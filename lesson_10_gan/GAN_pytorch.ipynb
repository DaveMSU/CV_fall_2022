# %% [markdown]
# # Generative Adversarial Networks
#
# Generative Adversarial Networks (GANs) are an approach to generative modeling based on deep learning methods.
#
# The standard problem settings for GANs are generation of photorealistic images and image-to-image translation tasks (translating photos of summer to winter, day to night etc.).
#
# In this task you will familiarize yourself with both these problems while trying to create fake images of sneakers.
#
# As GANs still do have certain limitations about generating large images, the task is decomposed into two: first, use a simple GAN to generate a bunch of low resolution images from noise, then upscale them using another generative model.

# %% [markdown]
# This notebook is built around [PyTorch](https://pytorch.org/) and [Lightning](https://pytorchlightning.ai/).

# %%
# %%bash
#
# if [ ! -d data/ ]; then
#     wget "https://www.dropbox.com/s/7dnwfvqxstr3j4v/data.zip?dl=0" -O data.zip --quiet
#     unzip -qq data.zip
# fi

# %%
# !pip install 'pytorch-lightning<1.8' --quiet

# %%
import os
import typing as tp

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pytorch_lightning as pl
import torch
import torch.nn as nn
import torchvision
import tqdm
from IPython.display import clear_output

# %matplotlib inline

# %%
BATCH_SIZE = 128
MEDIUM_BATCH_SIZE = 64
SMALL_BATCH_SIZE = 4
IMAGE_SIZE = (28, 28)
NOISE_DIM = 100
LOW_RES_SIZE = IMAGE_SIZE
HIGH_RES_SIZE = (112, 112)

# %%
train_kwargs = {}
if torch.cuda.is_available():
    train_kwargs['gpus'] = torch.cuda.device_count()

# %%
dataset_root = "./data"
images_dir = "images"
image_filenames = sorted(os.listdir(os.path.join(dataset_root, images_dir)))
len(image_filenames)
# Out:
# 5729

# %% [markdown]
# # I. Image Generation
#
# Your first task is to solve a problem of generating photorealistic images out of noise (okay, this might sound optimistic).
#
# Namely, you are required to **create fake images of sneakers of resolution 28x28 given a vector of noise sampled from standard normal distribution.**

# %% [markdown]
# Here is simple PyTorch `Dataset` class for loading and preprocessing

# %%
class SneakersDataset(torch.utils.data.Dataset):
    def __init__(
            self,
            root_dir: str,
            images_dir='images',
            input_size: tp.Optional[tp.Tuple[int, int]] = None,
            target_size: tp.Optional[tp.Tuple[int, int]] = None
        ):
        self.images_dir = os.path.join(root_dir, images_dir)
        self.input_size = input_size
        self.target_size = target_size
        self.all_images = sorted(
            [
                fname for fname in os.listdir(self.images_dir)
                if fname.endswith('.jpg')
            ]
        )
    
    def __len__(self) -> int:
        return len(self.all_images)
    
    def __getitem__(self, idx: int) -> tp.Any:
        image_path = os.path.join(self.images_dir, self.all_images[idx])
        image_bgr = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
        
        if self.input_size is not None:
            input_rgb = cv2.resize(image_rgb, self.input_size)
            input_rgb = (input_rgb / 255).astype(np.float32)
            
        if self.target_size is not None:
            image_rgb = cv2.resize(image_rgb, self.target_size)
        image_rgb = (image_rgb / 255).astype(np.float32)
        
        # tanh values in [-1, 1]
        if self.input_size is not None:
            return (
                torch.from_numpy(input_rgb * 2 - 1),
                torch.from_numpy(image_rgb * 2 - 1)
            )
        else:
            return torch.from_numpy(image_rgb * 2 - 1)

# %% [markdown]
# Here we create `LightningDataModule` which will handle dataset loading in our case

# %%
dataset = SneakersDataset(
    'data',
    target_size=IMAGE_SIZE
)

dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True
)

# %%
class SneakersGANDataModule(pl.LightningDataModule):
    def __init__(self, data_dir: str, batch_size, shuffle=True):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.shuffle = shuffle
    
    def setup(self, stage=None):
        self.dataset = SneakersDataset(self.data_dir, target_size=IMAGE_SIZE)
    
    def train_dataloader(self):
        return torch.utils.data.DataLoader(self.dataset, batch_size=self.batch_size, shuffle=self.shuffle)

# %%
def data2img(d: np.ndarray):
    return 0.5 * d + 0.5

def visualize_images(
        data: tp.Iterable,
        n_rows: int,
        n_cols: int
    ) -> None:
    n_samples = n_rows * n_cols
    if len(data) != n_samples:
        sample_indices = np.random.choice(
            len(data),
            n_samples,
            replace=len(data) < n_samples
        )
    else:
        sample_indices = np.arange(len(data)).astype(int)

    plt.figure(figsize=(int(2.5 * n_cols), int(2.5 * n_rows)))
    for i, sample_index in enumerate(sample_indices):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(data2img(data[sample_index]))
        plt.axis("off")
    plt.show()

# %%
dm = SneakersGANDataModule('data', batch_size=32)
dm.setup()
visualize_images(next(iter(dm.train_dataloader())), 4, 8)

# %% [markdown]
# ## Fully connected GAN

# %% [markdown]
# ### Generator (0.5 pts) [cross-check:0]
#
# Our first step is to build a generator. You should use the layers in `torch.nn` (imported in the beginning as `nn`) to construct the model. Since we are using PyTorch and Lightning, you should create `nn.Module`. Use the default initializers for parameters.
#
# Architecture:
#  * Fully connected (`Linear` in PyTorch) with output size of 1024
#  * ReLU
#  * Fully connected with output size of 1024
#  * ReLU
#  * Fully connected with output size of 28 x 28 x 3
#  * TanH (to restrict every element of the output to be in the range [-1,1])
#  * Reshape into (28, 28, 3)
#
# > You could perform reshaping inside of `forward` method

# %%
class FCGenerator(torch.nn.Module):
    def __init__(
            self,
            noize_dim: int,
            img_shape: tp.Tuple[int, int]
        ):
        super().__init__()
        self._img_shape = img_shape
        
        self._model = torch.nn.Sequential(
            torch.nn.Linear(
                in_features=noize_dim, 
                out_features=1024
            ),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(
                in_features=1024, 
                out_features=1024
            ),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(
                in_features=1024, 
                out_features=28 * 28 * 3
            ),
            torch.nn.Tanh()

        )
    
    def forward(self, z):
        img = self._model(z)
        img = img.view(img.size(0), *self._img_shape)  # keep batch size
        return img

# %%
fc_gen = FCGenerator(NOISE_DIM, IMAGE_SIZE + (3,))
img_generated = fc_gen(torch.randn(32, NOISE_DIM))
assert img_generated.shape[1:] == IMAGE_SIZE + (3,)

# %% [markdown]
# ### Discriminator (0.5 pts) [cross-check:1]
#
# Now you are to build a discriminator. You should use the default initializers for parameters here as well.
#
# Architecture:
#  * Flatten
#  * Fully connected with output size of 256
#  * Leaky ReLU(0.01)
#  * Fully connected with output size of 256
#  * Leaky ReLU(0.01)
#  * Fully connected with output size of 1
#  * Sigmoid (to obtain logits as an output)
#
# The output of the discriminator should thus have shape `[batch_size, 1]`, and contain real numbers corresponding to the probability that each of the `batch_size` inputs is a real image.
#
# > You could perform flattening inside of `forward` method

# %%
class FCDiscriminator(torch.nn.Module):
    def __init__(self, img_shape: tp.Tuple[int, int]):
        super().__init__()
        self._model = torch.nn.Sequential(
            torch.nn.Linear(
                in_features=np.prod(img_shape),
                out_features=256
            ),
            torch.nn.LeakyReLU(negative_slope=0.01),
            torch.nn.Linear(
                in_features=256,
                out_features=256
            ),
            torch.nn.LeakyReLU(negative_slope=0.01),
            torch.nn.Linear(
                in_features=256,
                out_features=1
            ),
            torch.nn.Sigmoid()
        )
    
    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        return self._model(img_flat)

# %%
fc_dis = FCDiscriminator(IMAGE_SIZE + (3,))
prob_dis = fc_dis(img_generated)
assert prob_dis.shape[1:] == (1,)

# %% [markdown]
# ## GAN Loss (1.0 pts) [cross-check:2]
#
# Compute the generator and discriminator loss. The generator loss is:
# $$\ell_G  =  -\mathbb{E}_{z \sim p(z)}\left[\log D(G(z))\right]$$
# and the discriminator loss is:
# $$ \ell_D = -\mathbb{E}_{x \sim p_\text{data}}\left[\log D(x)\right] - \mathbb{E}_{z \sim p(z)}\left[\log \left(1-D(G(z))\right)\right]$$
#
# Instead of computing the expectation, you may average over elements of the minibatch, so make sure to combine the loss by *averaging* instead of summing.
#
# Note that these are negated from the equations presented earlier as we will be *minimizing* these losses.

# %% [markdown]
# There is a `LightningModule` with all necessary methods. You should fill all `TODO` comments.
#
# > Don't forget to use `detach` method for discriminator training step to prevent backpropagation for generator compuational graph

# %%
# generator_loss = lambda p, t: torch.nn.BCELoss(reduction="mean")(p, t)
# discriminator_loss = lambda p, t: torch.nn.BCELoss(reduction="mean")(p, t)

# %%
fc_dis = FCDiscriminator(IMAGE_SIZE + (3,))
fc_gen = FCGenerator(NOISE_DIM, IMAGE_SIZE + (3,))

loss = torch.nn.BCELoss(reduction="mean")
optimizer_dis = torch.optim.Adam(fc_dis.parameters(), lr=0.0001)
optimizer_gen = torch.optim.Adam(fc_gen.parameters(), lr=0.0001)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
fc_dis = fc_dis.to(device)
fc_gen = fc_gen.to(device)
device
# Out:
# device(type='cuda', index=0)

# %%
# epoch_nums = 10

# fc_dis = fc_dis.eval()
# fc_gen = fc_gen.train()

# for epoch in range(epoch_nums):
#     for real_batch in dataloader:
#         optimizer_gen.zero_grad()

#         noize = torch.randn(BATCH_SIZE, NOISE_DIM)
#         noize = noize.to(device)
#         fake_batch = fc_gen(noize)
#         y = torch.ones(BATCH_SIZE, 1).to(device)
#         y_pred = fc_dis(fake_batch)
#         loss_value = -loss(y_pred, y)
#         loss_value.backward()
#         optimizer_gen.step()

#         X = torch.concat((real_batch, fake_batch))
#         y = torch.concat((torch.zeros(BATCH_SIZE, 1), torch.ones(BATCH_SIZE, 1)))
#         X = X.to(device)
#         y = y.to(device)
#         y_pred = fc_dis(X)
#         loss_value = loss(y_pred, y)        
    
#         print(epoch, loss_value.data, (y == (y_pred > 0.5).long()).cpu().numpy().mean())

# %%
optimizer_indx = 0

# %%
epoch_nums = 1000

for epoch in range(epoch_nums):
    optimizer_indx = epoch % 2
    for real_batch in dataloader:
        optimizer_dis.zero_grad()
        optimizer_gen.zero_grad()
        if optimizer_indx == 0:
            fc_gen = fc_gen.eval()
            fc_dis = fc_dis.train()
            noize = torch.randn(BATCH_SIZE, NOISE_DIM)
            noize = noize.to(device)
            fake_batch = fc_gen(noize).detach().cpu()
            X = torch.concat((real_batch, fake_batch))
            y = torch.concat((torch.zeros(BATCH_SIZE, 1), torch.ones(BATCH_SIZE, 1)))
            X = X.to(device)
            y = y.to(device)
            y_pred = fc_dis(X)
            loss_value = loss(y_pred, y)
            loss_value.backward()
            optimizer_dis.step()
        else:
            fc_dis = fc_dis.eval()
            fc_gen = fc_gen.train()
            noize = torch.randn(BATCH_SIZE, NOISE_DIM)
            noize = noize.to(device)
            fake_batch = fc_gen(noize)
            y = torch.ones(BATCH_SIZE, 1).to(device)
            y_pred = fc_dis(fake_batch)
            loss_value = -loss(y_pred, y)
            loss_value.backward()
            optimizer_gen.step()
        print(epoch, 1 - optimizer_indx, loss_value.data, (y == (y_pred > 0.5).long()).cpu().numpy().mean())

    # optimizer_indx = 1 - optimizer_indx

        if optimizer_indx == 0 and np.isclose((y == (y_pred > 0.5).long()).cpu().numpy().mean(), 1.0):
            optimizer_indx = 1 - optimizer_indx
        elif optimizer_indx == 1 and np.isclose((y == (y_pred > 0.5).long()).cpu().numpy().mean(), 0.0):
            optimizer_indx = 1 - optimizer_indx

# %%
# class FCGAN(pl.LightningModule):
#     def __init__(self, width, height, channels, noise_dim=100, lr=0.0002, b1=0.5, b2=0.999):
#         super().__init__()
#         self.save_hyperparameters()  # make <arg> available as self.hparams.<arg>
        
#         img_shape = (width, height, channels)
#         self.generator = FCGenerator(noise_dim=self.hparams.noise_dim, img_shape=img_shape)
#         self.discriminator = FCDiscriminator(img_shape=img_shape)
        
#         self.validation_z = torch.randn(8, noise_dim)
    
#     def forward(self, z):
#         return self.generator(z)
    
#     def gan_loss(self, y_hat, y):
#         return  # TODO: implement GAN loss (hint: binary cross entropy)
    
#     def training_step(self, imgs, batch_idx, optimizer_idx):
#         z = torch.randn(imgs.size(0), self.hparams.noise_dim)
#         z = z.type_as(imgs)  # move to same device as imgs
        
#         if optimizer_idx == 0:  # generator
#             self.generated_imgs = self(z)
            
#             valid = torch.ones(imgs.size(0), 1)  # all fake, but we want to be real
#             valid = valid.type_as(imgs)
            
#             g_loss = self.gan_loss(self.discriminator(self(z)), valid)
#             self.log('g_loss', g_loss, prog_bar=True)
#             return {'loss': g_loss}
        
#         if optimizer_idx == 1:  # discriminator
#             valid = torch.ones(imgs.size(0), 1)
#             valid = valid.type_as(imgs)
#             real_loss = # TODO: loss for `discriminator(imgs)` and `valid`
            
#             fake = # TODO: zero vector for fake_loss computation
#             fake = fake.type_as(imgs)

#             fake_loss = self.gan_loss(self.discriminator(self(z).detach()), fake)
            
#             d_loss = (real_loss + fake_loss) / 2
#             self.log('d_loss', d_loss, prog_bar=True)
#             return {'loss': d_loss}
    
#     def configure_optimizers(self):
#         lr = self.hparams.lr
#         b1 = self.hparams.b1
#         b2 = self.hparams.b2

#         opt_g = torch.optim.Adam(self.generator.parameters(), lr=lr, betas=(b1, b2))
#         opt_d = torch.optim.Adam(self.discriminator.parameters(), lr=lr, betas=(b1, b2))
#         return [opt_g, opt_d], []

#     def on_epoch_end(self):
#         # send results for validation_z to TensorBoard
#         z = self.validation_z.type_as(self.generator.model[0].weight)
#         sample_imgs = self(z).permute(0, 3, 1, 2)  # channels before pixels
#         grid = torchvision.utils.make_grid(sample_imgs)
#         self.logger.experiment.add_image('generated_images', grid, self.current_epoch)

# %% [markdown]
# #### Training

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs

# %%
# train_kwargs['max_epochs'] = 100

# %%
# dm = SneakersGANDataModule('data', batch_size=BATCH_SIZE)
# model = FCGAN(*IMAGE_SIZE, 3, NOISE_DIM)
# trainer = pl.Trainer(**train_kwargs)
# trainer.fit(model, dm)

# %%
visualize_images(fc_gen(torch.randn(32, NOISE_DIM).to(device)).cpu().detach(), 4, 8)

# %% [markdown]
# > Hint: this architecture isn't great, so don't spend all your time to train it

# %% [markdown]
# ## Deep Convolutional GANs
# In the first part of the notebook, you have implemented an almost direct copy of the original GAN network from Ian Goodfellow. However, this network architecture allows no real spatial reasoning. It is unable to reason about things like "sharp edges" in general because it lacks any convolutional layers. Thus, in this section, you are to implement some of the ideas from [DCGAN](https://arxiv.org/abs/1511.06434), where both discriminator and generator are convolutional networks.

# %% [markdown]
# ### Generator (1.0 pts) [cross-check:3]
#
# Architecture:
#  * Fully connected with output size of 128x7x7
#  * Reshape into (128, 7, 7)
#  * ReLU
#  * UpSampling2D(2)
#  * Conv2D: 3x3, filters=128, padding="same"
#  * Batch Normalization 2D with momentum(0.8)
#  * ReLU
#  * UpSampling2D(2)
#  * Conv2D: 3x3, filters=64, padding="same"
#  * Batch Normalization 2D with momentum(0.8)
#  * ReLU
#  * Conv2D: 3x3, filters=3, padding="same"
#  * TanH (to restrict every element of the output to be in the range [-1,1])
#
# > There is no `padding="same"` in PyTorch, but you could use `padding=k//2` and `padding_mode="zeros"` for kernel size `k`

# %%
class DCGenerator(torch.nn.Module):
    def __init__(
            self,
            noise_dim: int,
            img_shape: tp.Tuple[int, int]
        ):
        super().__init__()
        self._img_shape = img_shape

        self._first_fc = torch.nn.Linear(
           in_features=noise_dim,
           out_features=128 * 7 * 7
        )
        
        self._model = torch.nn.Sequential(
            torch.nn.ReLU(inplace=True),
            torch.nn.Upsample(scale_factor=2, mode='bilinear'),
            torch.nn.Conv2d(
                in_channels=128,
                out_channels=64,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.ReLU(inplace=True),
            torch.nn.BatchNorm2d(
                num_features=64,
                momentum=0.8
            ),
            torch.nn.Upsample(scale_factor=2, mode='bilinear'),
            torch.nn.Conv2d(
                in_channels=64,
                out_channels=64,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.BatchNorm2d(
                num_features=64,
                momentum=0.8
            ),            
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(
                in_channels=64,
                out_channels=3,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.Tanh()
        )
    
    def forward(self, z):
        img = self._first_fc(z)
        img = img.view(img.size(0), 128, 7, 7)  # keep batch size
        img = self._model(img)
        img = img.permute(0, 2, 3, 1)  # make channel axis last
        return img

# %%
dc_gen = DCGenerator(NOISE_DIM, IMAGE_SIZE + (3,))
fake_imgs = dc_gen(torch.randn(10, NOISE_DIM))
assert fake_imgs.shape[1:] == IMAGE_SIZE + (3,)

# %% [markdown]
# ### Discriminator (1.0 pts) [cross-check:4]
#
# Architecture:
#  * Conv2D: 3x3, filters=32, strides=2, padding="same"
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=64, strides=2, padding="same"
#  * Zero Padding 2D: ((0, 1), (0, 1))
#  * Batch Normalization 2D with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=128, strides=2, padding="same"
#  * Batch Normalization 2D with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Conv2D: 3x3, filters=256, strides=2, padding="same"
#  * Batch Normalization 2D with momentum(0.8)
#  * Leaky ReLU(0.2)
#  * Dropout(0.25)
#  * Flatten
#  * Fully connected layer with output size 1
#  * Sigmoid

# %%
class DCDiscriminator(torch.nn.Module):
    def __init__(self, img_shape: tuple):
        super().__init__()

        self.model = torch.nn.Sequential(
            torch.nn.Conv2d(
                in_channels=3,
                out_channels=32,
                kernel_size=(3, 3),
                stride=(2, 2),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.LeakyReLU(negative_slope=0.2),
            torch.nn.Dropout(p=0.25),
            torch.nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=(3, 3),
                stride=(2, 2),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.ZeroPad2d(padding=(0, 1, 0, 1)),
            torch.nn.BatchNorm2d(
                num_features=64,
                momentum=0.8
            ),
            torch.nn.LeakyReLU(negative_slope=0.2),
            torch.nn.Dropout(p=0.25),
            torch.nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=(3, 3),
                stride=(2, 2),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.BatchNorm2d(
                num_features=128,
                momentum=0.8
            ),
            torch.nn.LeakyReLU(negative_slope=0.2),
            torch.nn.Dropout(p=0.25),
            torch.nn.Flatten(),
            torch.nn.Linear(
                in_features=128 * 4 * 4,
                out_features=1
            ),
            torch.nn.Sigmoid()
        )
    
    def forward(self, img):
        img_chan = img.permute(0, 3, 1, 2)  # channels first
        return self.model(img_chan)

# %%
dc_dis = DCDiscriminator(img_shape=IMAGE_SIZE + (3,))
fake_proba = dc_dis(fake_imgs)
assert fake_proba.shape[1:] == (1,)

# %% [markdown]
# ## Least Squares GAN loss (1.0 pts) [cross-check:5]
# We'll now look at [Least Squares GAN loss](https://arxiv.org/abs/1611.04076), a newer, more stable alternative to the original GAN loss function. For this part, all you have to do is change the loss function and retrain the model. You'll implement equation (9) in the paper, with the generator loss:
# $$\ell_G  =  \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[\left(D(G(z))-1\right)^2\right]$$
# and the discriminator loss:
# $$ \ell_D = \frac{1}{2}\mathbb{E}_{x \sim p_\text{data}}\left[\left(D(x)-1\right)^2\right] + \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[ \left(D(G(z))\right)^2\right]$$

# %%
loss_dis = lambda y_pred, y: (
    -(
        torch.log(y_pred[y == 1]) +
        torch.log((1 - y_pred[y == 0]))
    ) * 0.5
).mean()

loss_gen = lambda y_pred, y: -torch.log(1 - y_pred[y == 1]).mean()

# %%
loss_dis = lambda y_pred, y: (
    -(
        torch.log(y_pred[y == 1] ** 2) +
        torch.log((1 - y_pred[y == 0])**2)
    ) * 0.5
).mean()

loss_gen = lambda y_pred, y: -torch.log((1 - y_pred[y == 1]) ** 2).mean()

# %%
loss_dis = lambda y_pred, y: (y_pred[y == 1] ** 2 + (1 - y_pred[y == 0])**2).mean() * 0.5
loss_gen = lambda y_pred, y: ((1 - y_pred[y == 1]) ** 2).mean() * 0.5

# %%
# class DCGAN(pl.LightningModule):
#     def __init__(self, width, height, channels, noise_dim=100, lr=0.0002, b1=0.5, b2=0.999):
#         super().__init__()
#         self.save_hyperparameters()  # make <arg> available as self.hparams.<arg>
        
#         img_shape = (width, height, channels)
#         self.generator = DCGenerator(noise_dim=self.hparams.noise_dim, img_shape=img_shape)
#         self.discriminator = DCDiscriminator(img_shape=img_shape)
        
#         self.validation_z = torch.randn(8, noise_dim)
        
#     def forward(self, z):
#         return self.generator(z)
    
#     def ls_loss(self, y_hat, y):
#         return  # TODO: implement least squares GAN loss
    
#     def training_step(self, imgs, batch_idx, optimizer_idx):
#         z = torch.randn(imgs.size(0), self.hparams.noise_dim)
#         z = z.type_as(imgs)  # move to same device as imgs
        
#         if optimizer_idx == 0:  # generator
#             # TODO: compute loss as before (FCGAN)
            
#             self.log('g_loss', g_loss, prog_bar=True)
#             return {'loss': g_loss}
        
#         if optimizer_idx == 1:  # discriminator
#             # TODO: compute loss as before (FCGAN)
            
#             self.log('d_loss', d_loss, prog_bar=True)
#             return {'loss': d_loss}
    
#     def configure_optimizers(self):
#         lr = self.hparams.lr
#         b1 = self.hparams.b1
#         b2 = self.hparams.b2

#         opt_g = torch.optim.Adam(self.generator.parameters(), lr=lr, betas=(b1, b2))
#         opt_d = torch.optim.Adam(self.discriminator.parameters(), lr=lr, betas=(b1, b2))
#         return [opt_g, opt_d], []

#     def on_epoch_end(self):
#         z = self.validation_z.type_as(self.generator.model[0].weight)
#         sample_imgs = self(z).permute(0, 3, 1, 2)  # channels before pixels
#         grid = torchvision.utils.make_grid(sample_imgs)
#         self.logger.experiment.add_image('generated_images', grid, self.current_epoch)

# %% [markdown]
# ### Training
# Train generator and discriminator in a loop and draw results once every N iterations.

# %%
dl_dis = DCDiscriminator(IMAGE_SIZE + (3,))
dl_gen = DCGenerator(NOISE_DIM, IMAGE_SIZE + (3,))

loss = torch.nn.BCELoss(reduction="mean")
optimizer_dis = torch.optim.Adam(dl_dis.parameters(), lr=0.0001)
optimizer_gen = torch.optim.Adam(dl_gen.parameters(), lr=0.0001)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
dl_dis = dl_dis.to(device)
dl_gen = dl_gen.to(device)
device
# Out:
# device(type='cuda', index=0)

# %%
epoch_nums = 150  # 500

dl_dis = dl_dis.to(device)
dl_gen = dl_gen.to(device)

for epoch in range(epoch_nums):
    optimizer_indx = epoch % 2
    for real_batch in dataloader:
        optimizer_dis.zero_grad()
        optimizer_gen.zero_grad()
        if optimizer_indx == 0:
            dl_gen = dl_gen.eval()
            dl_dis = dl_dis.train()
            noize = torch.randn(BATCH_SIZE, NOISE_DIM)
            noize = noize.to(device)
            fake_batch = dl_gen(noize).detach().cpu()
            X = torch.concat((real_batch, fake_batch))
            y = torch.concat((torch.zeros(BATCH_SIZE, 1), torch.ones(BATCH_SIZE, 1)))
            X = X.to(device)
            y = y.to(device)
            y_pred = dl_dis(X)
            loss_value = loss_dis(y_pred, y)
            loss_value.backward()
            optimizer_dis.step()
        else:
            dl_dis = dl_dis.eval()
            dl_gen = dl_gen.train()
            noize = torch.randn(BATCH_SIZE, NOISE_DIM)
            noize = noize.to(device)
            fake_batch = dl_gen(noize)
            y = torch.ones(BATCH_SIZE, 1).to(device)
            y_pred = dl_dis(fake_batch)
            loss_value = loss_gen(y_pred, y)            
            loss_value.backward()
            optimizer_gen.step()
        print(epoch, 1 - optimizer_indx, loss_value.data, (y == (y_pred > 0.5).long()).cpu().numpy().mean())

        optimizer_indx = 1 - optimizer_indx

        # if optimizer_indx == 0 and np.isclose((y == (y_pred > 0.5).long()).cpu().numpy().mean(), 1.0):
        #     optimizer_indx = 1 - optimizer_indx
        # elif optimizer_indx == 1 and np.isclose((y == (y_pred > 0.5).long()).cpu().numpy().mean(), 0.0):
        #     optimizer_indx = 1 - optimizer_indx
# Out:
# 0 1 tensor(0.1482, device='cuda:0') 0.16796875
# 0 0 tensor(0.3715, device='cuda:0') 0.0
# 0 1 tensor(0.1309, device='cuda:0') 0.16015625
# 0 0 tensor(0.3573, device='cuda:0') 0.0
# 0 1 tensor(0.1398, device='cuda:0') 0.1953125
# 0 0 tensor(0.3680, device='cuda:0') 0.0
# 0 1 tensor(0.1507, device='cuda:0') 0.1796875
# 0 0 tensor(0.3558, device='cuda:0') 0.0
# 0 1 tensor(0.1347, device='cuda:0') 0.1796875
# 0 0 tensor(0.3562, device='cuda:0') 0.0
# 0 1 tensor(0.1374, device='cuda:0') 0.1796875
# 0 0 tensor(0.3633, device='cuda:0') 0.0
# 0 1 tensor(0.1213, device='cuda:0') 0.1640625
# 0 0 tensor(0.3703, device='cuda:0') 0.0078125
# 0 1 tensor(0.1297, device='cuda:0') 0.15234375
# 0 0 tensor(0.3580, device='cuda:0') 0.0
# 0 1 tensor(0.1207, device='cuda:0') 0.1328125
# 0 0 tensor(0.3653, device='cuda:0') 0.0
# 0 1 tensor(0.1218, device='cuda:0') 0.1484375
# 0 0 tensor(0.3683, device='cuda:0') 0.0
# 0 1 tensor(0.0929, device='cuda:0') 0.08984375
# 0 0 tensor(0.3670, device='cuda:0') 0.0
# 0 1 tensor(0.0990, device='cuda:0') 0.109375
# 0 0 tensor(0.3714, device='cuda:0') 0.0
# 0 1 tensor(0.1299, device='cuda:0') 0.1640625
# 0 0 tensor(0.3768, device='cuda:0') 0.0
# 0 1 tensor(0.0899, device='cuda:0') 0.0859375
# 0 0 tensor(0.3773, device='cuda:0') 0.0
# 0 1 tensor(0.1032, device='cuda:0') 0.10546875
# 0 0 tensor(0.3680, device='cuda:0') 0.0
# 0 1 tensor(0.1076, device='cuda:0') 0.1171875
# 0 0 tensor(0.3837, device='cuda:0') 0.0
# 0 1 tensor(0.1125, device='cuda:0') 0.13671875
# 0 0 tensor(0.3711, device='cuda:0') 0.0
# 0 1 tensor(0.0914, device='cuda:0') 0.08203125
# 0 0 tensor(0.3726, device='cuda:0') 0.0
# 0 1 tensor(0.1208, device='cuda:0') 0.125
# 0 0 tensor(0.3746, device='cuda:0') 0.0
# 0 1 tensor(0.1011, device='cuda:0') 0.11328125
# 0 0 tensor(0.3772, device='cuda:0') 0.0
# 0 1 tensor(0.1147, device='cuda:0') 0.12109375
# 0 0 tensor(0.3775, device='cuda:0') 0.0
# 0 1 tensor(0.1092, device='cuda:0') 0.12109375
# 0 0 tensor(0.3751, device='cuda:0') 0.0
# 1 0 tensor(0.3535, device='cuda:0') 0.0
# 1 1 tensor(0.1600, device='cuda:0') 0.2265625
# 1 0 tensor(0.3543, device='cuda:0') 0.0
# 1 1 tensor(0.1134, device='cuda:0') 0.140625
# 1 0 tensor(0.3642, device='cuda:0') 0.0
# 1 1 tensor(0.1110, device='cuda:0') 0.109375
# 1 0 tensor(0.3782, device='cuda:0') 0.0
# 1 1 tensor(0.1163, device='cuda:0') 0.125
# 1 0 tensor(0.3841, device='cuda:0') 0.0
# 1 1 tensor(0.1260, device='cuda:0') 0.15234375
# 1 0 tensor(0.3836, device='cuda:0') 0.0
# 1 1 tensor(0.1183, device='cuda:0') 0.1484375
# 1 0 tensor(0.3869, device='cuda:0') 0.0
# 1 1 tensor(0.1110, device='cuda:0') 0.1328125
# 1 0 tensor(0.3919, device='cuda:0') 0.0
# 1 1 tensor(0.1214, device='cuda:0') 0.13671875
# 1 0 tensor(0.3959, device='cuda:0') 0.0
# 1 1 tensor(0.1274, device='cuda:0') 0.15234375
# 1 0 tensor(0.3891, device='cuda:0') 0.0
# 1 1 tensor(0.1259, device='cuda:0') 0.1484375
# 1 0 tensor(0.3963, device='cuda:0') 0.0
# 1 1 tensor(0.1124, device='cuda:0') 0.15234375
# 1 0 tensor(0.3992, device='cuda:0') 0.0
# 1 1 tensor(0.1228, device='cuda:0') 0.15625
# 1 0 tensor(0.3987, device='cuda:0') 0.0
# 1 1 tensor(0.1234, device='cuda:0') 0.1484375
# 1 0 tensor(0.4075, device='cuda:0') 0.0
# 1 1 tensor(0.1359, device='cuda:0') 0.15625
# 1 0 tensor(0.4054, device='cuda:0') 0.0
# 1 1 tensor(0.1299, device='cuda:0') 0.1484375
# 1 0 tensor(0.3998, device='cuda:0') 0.0078125
# 1 1 tensor(0.1081, device='cuda:0') 0.14453125
# 1 0 tensor(0.4074, device='cuda:0') 0.0078125
# 1 1 tensor(0.1121, device='cuda:0') 0.14453125
# 1 0 tensor(0.3979, device='cuda:0') 0.0078125
# 1 1 tensor(0.1021, device='cuda:0') 0.140625
# 1 0 tensor(0.4024, device='cuda:0') 0.0
# 1 1 tensor(0.1059, device='cuda:0') 0.1171875
# 1 0 tensor(0.4054, device='cuda:0') 0.0
# 1 1 tensor(0.1226, device='cuda:0') 0.171875
# 1 0 tensor(0.3945, device='cuda:0') 0.0078125
# 1 1 tensor(0.1222, device='cuda:0') 0.16015625
# 1 0 tensor(0.3975, device='cuda:0') 0.0078125
# 1 1 tensor(0.1153, device='cuda:0') 0.15234375
# 2 1 tensor(0.1137, device='cuda:0') 0.1328125
# 2 0 tensor(0.4145, device='cuda:0') 0.0
# 2 1 tensor(0.0906, device='cuda:0') 0.11328125
# 2 0 tensor(0.4084, device='cuda:0') 0.0
# 2 1 tensor(0.1085, device='cuda:0') 0.125
# 2 0 tensor(0.4128, device='cuda:0') 0.0
# 2 1 tensor(0.1167, device='cuda:0') 0.1484375
# 2 0 tensor(0.4089, device='cuda:0') 0.0
# 2 1 tensor(0.1100, device='cuda:0') 0.1484375
# 2 0 tensor(0.4065, device='cuda:0') 0.0
# 2 1 tensor(0.1138, device='cuda:0') 0.1171875
# 2 0 tensor(0.4091, device='cuda:0') 0.0
# 2 1 tensor(0.1399, device='cuda:0') 0.17578125
# 2 0 tensor(0.4069, device='cuda:0') 0.015625
# 2 1 tensor(0.1083, device='cuda:0') 0.13671875
# 2 0 tensor(0.4112, device='cuda:0') 0.0078125
# 2 1 tensor(0.0983, device='cuda:0') 0.125
# 2 0 tensor(0.4059, device='cuda:0') 0.0
# 2 1 tensor(0.1429, device='cuda:0') 0.16796875
# 2 0 tensor(0.3966, device='cuda:0') 0.015625
# 2 1 tensor(0.1359, device='cuda:0') 0.1796875
# 2 0 tensor(0.4035, device='cuda:0') 0.0078125
# 2 1 tensor(0.1269, device='cuda:0') 0.1484375
# 2 0 tensor(0.4112, device='cuda:0') 0.0
# 2 1 tensor(0.1413, device='cuda:0') 0.20703125
# 2 0 tensor(0.3854, device='cuda:0') 0.015625
# 2 1 tensor(0.1015, device='cuda:0') 0.11328125
# 2 0 tensor(0.3874, device='cuda:0') 0.0078125
# 2 1 tensor(0.1542, device='cuda:0') 0.21484375
# 2 0 tensor(0.3877, device='cuda:0') 0.0234375
# 2 1 tensor(0.1368, device='cuda:0') 0.19921875
# 2 0 tensor(0.3847, device='cuda:0') 0.015625
# 2 1 tensor(0.1820, device='cuda:0') 0.23828125
# 2 0 tensor(0.3867, device='cuda:0') 0.015625
# 2 1 tensor(0.1341, device='cuda:0') 0.171875
# 2 0 tensor(0.4030, device='cuda:0') 0.0078125
# 2 1 tensor(0.1640, device='cuda:0') 0.22265625
# 2 0 tensor(0.3850, device='cuda:0') 0.015625
# 2 1 tensor(0.1824, device='cuda:0') 0.25390625
# 2 0 tensor(0.4006, device='cuda:0') 0.0078125
# 2 1 tensor(0.1363, device='cuda:0') 0.1796875
# 2 0 tensor(0.4044, device='cuda:0') 0.0
# 2 1 tensor(0.1688, device='cuda:0') 0.22265625
# 2 0 tensor(0.4035, device='cuda:0') 0.0234375
# 3 0 tensor(0.3866, device='cuda:0') 0.03125
# 3 1 tensor(0.1378, device='cuda:0') 0.19140625
# 3 0 tensor(0.4002, device='cuda:0') 0.0078125
# 3 1 tensor(0.1465, device='cuda:0') 0.20703125
# 3 0 tensor(0.4006, device='cuda:0') 0.0078125
# 3 1 tensor(0.1797, device='cuda:0') 0.2578125
# 3 0 tensor(0.3798, device='cuda:0') 0.015625
# 3 1 tensor(0.2053, device='cuda:0') 0.26953125
# 3 0 tensor(0.3673, device='cuda:0') 0.0546875
# 3 1 tensor(0.1914, device='cuda:0') 0.26953125
# 3 0 tensor(0.3839, device='cuda:0') 0.03125
# 3 1 tensor(0.2112, device='cuda:0') 0.28515625
# 3 0 tensor(0.3751, device='cuda:0') 0.046875
# 3 1 tensor(0.1852, device='cuda:0') 0.26953125
# 3 0 tensor(0.3746, device='cuda:0') 0.0234375
# 3 1 tensor(0.1722, device='cuda:0') 0.24609375
# 3 0 tensor(0.3849, device='cuda:0') 0.0234375
# 3 1 tensor(0.1974, device='cuda:0') 0.28515625
# 3 0 tensor(0.3867, device='cuda:0') 0.015625
# 3 1 tensor(0.1922, device='cuda:0') 0.26953125
# 3 0 tensor(0.3676, device='cuda:0') 0.0390625
# 3 1 tensor(0.2013, device='cuda:0') 0.3046875
# 3 0 tensor(0.3580, device='cuda:0') 0.0625
# 3 1 tensor(0.2105, device='cuda:0') 0.29296875
# 3 0 tensor(0.3646, device='cuda:0') 0.03125
# 3 1 tensor(0.1858, device='cuda:0') 0.2578125
# 3 0 tensor(0.3659, device='cuda:0') 0.0234375
# 3 1 tensor(0.1976, device='cuda:0') 0.265625
# 3 0 tensor(0.3494, device='cuda:0') 0.078125
# 3 1 tensor(0.2094, device='cuda:0') 0.3046875
# 3 0 tensor(0.3320, device='cuda:0') 0.09375
# 3 1 tensor(0.1881, device='cuda:0') 0.23828125
# 3 0 tensor(0.3598, device='cuda:0') 0.0546875
# 3 1 tensor(0.2026, device='cuda:0') 0.3125
# 3 0 tensor(0.3712, device='cuda:0') 0.046875
# 3 1 tensor(0.2214, device='cuda:0') 0.3203125
# 3 0 tensor(0.3475, device='cuda:0') 0.09375
# 3 1 tensor(0.2213, device='cuda:0') 0.3359375
# 3 0 tensor(0.3504, device='cuda:0') 0.078125
# 3 1 tensor(0.1723, device='cuda:0') 0.265625
# 3 0 tensor(0.3404, device='cuda:0') 0.0390625
# 3 1 tensor(0.2101, device='cuda:0') 0.30078125
# 3 0 tensor(0.3653, device='cuda:0') 0.0234375
# 3 1 tensor(0.1714, device='cuda:0') 0.2578125
# 4 1 tensor(0.1674, device='cuda:0') 0.21484375
# 4 0 tensor(0.3586, device='cuda:0') 0.0390625
# 4 1 tensor(0.1849, device='cuda:0') 0.2734375
# 4 0 tensor(0.3715, device='cuda:0') 0.03125
# 4 1 tensor(0.1788, device='cuda:0') 0.26171875
# 4 0 tensor(0.3701, device='cuda:0') 0.0546875
# 4 1 tensor(0.1809, device='cuda:0') 0.25
# 4 0 tensor(0.3628, device='cuda:0') 0.0546875
# 4 1 tensor(0.1806, device='cuda:0') 0.265625
# 4 0 tensor(0.3645, device='cuda:0') 0.078125
# 4 1 tensor(0.1731, device='cuda:0') 0.23828125
# 4 0 tensor(0.3416, device='cuda:0') 0.078125
# 4 1 tensor(0.1520, device='cuda:0') 0.21484375
# 4 0 tensor(0.3523, device='cuda:0') 0.109375
# 4 1 tensor(0.2057, device='cuda:0') 0.29296875
# 4 0 tensor(0.3676, device='cuda:0') 0.0625
# 4 1 tensor(0.2051, device='cuda:0') 0.3046875
# 4 0 tensor(0.3649, device='cuda:0') 0.1171875
# 4 1 tensor(0.1911, device='cuda:0') 0.26953125
# 4 0 tensor(0.3465, device='cuda:0') 0.125
# 4 1 tensor(0.1919, device='cuda:0') 0.29296875
# 4 0 tensor(0.3266, device='cuda:0') 0.1875
# 4 1 tensor(0.2166, device='cuda:0') 0.30078125
# 4 0 tensor(0.3021, device='cuda:0') 0.203125
# 4 1 tensor(0.2035, device='cuda:0') 0.265625
# 4 0 tensor(0.3346, device='cuda:0') 0.171875
# 4 1 tensor(0.2015, device='cuda:0') 0.2734375
# 4 0 tensor(0.2916, device='cuda:0') 0.3046875
# 4 1 tensor(0.2220, device='cuda:0') 0.31640625
# 4 0 tensor(0.3228, device='cuda:0') 0.1953125
# 4 1 tensor(0.1998, device='cuda:0') 0.28125
# 4 0 tensor(0.2970, device='cuda:0') 0.296875
# 4 1 tensor(0.1909, device='cuda:0') 0.29296875
# 4 0 tensor(0.3097, device='cuda:0') 0.234375
# 4 1 tensor(0.1876, device='cuda:0') 0.2734375
# 4 0 tensor(0.3240, device='cuda:0') 0.1484375
# 4 1 tensor(0.1832, device='cuda:0') 0.265625
# 4 0 tensor(0.3220, device='cuda:0') 0.140625
# 4 1 tensor(0.1931, device='cuda:0') 0.30859375
# 4 0 tensor(0.3288, device='cuda:0') 0.1328125
# 4 1 tensor(0.1590, device='cuda:0') 0.234375
# 4 0 tensor(0.3447, device='cuda:0') 0.0703125
# 4 1 tensor(0.1810, device='cuda:0') 0.2734375
# 4 0 tensor(0.3383, device='cuda:0') 0.109375
# 5 0 tensor(0.3352, device='cuda:0') 0.1171875
# 5 1 tensor(0.1488, device='cuda:0') 0.203125
# 5 0 tensor(0.3667, device='cuda:0') 0.0390625
# 5 1 tensor(0.1750, device='cuda:0') 0.26953125
# 5 0 tensor(0.3481, device='cuda:0') 0.0625
# 5 1 tensor(0.1511, device='cuda:0') 0.2421875
# 5 0 tensor(0.3558, device='cuda:0') 0.0703125
# 5 1 tensor(0.1451, device='cuda:0') 0.22265625
# 5 0 tensor(0.3656, device='cuda:0') 0.0234375
# 5 1 tensor(0.1412, device='cuda:0') 0.21875
# 5 0 tensor(0.3533, device='cuda:0') 0.046875
# 5 1 tensor(0.1294, device='cuda:0') 0.17578125
# 5 0 tensor(0.3710, device='cuda:0') 0.0390625
# 5 1 tensor(0.1355, device='cuda:0') 0.22265625
# 5 0 tensor(0.3715, device='cuda:0') 0.0390625
# 5 1 tensor(0.1172, device='cuda:0') 0.15234375
# 5 0 tensor(0.3609, device='cuda:0') 0.03125
# 5 1 tensor(0.1088, device='cuda:0') 0.16015625
# 5 0 tensor(0.3401, device='cuda:0') 0.0546875
# 5 1 tensor(0.1037, device='cuda:0') 0.14453125
# 5 0 tensor(0.3674, device='cuda:0') 0.015625
# 5 1 tensor(0.1213, device='cuda:0') 0.16015625
# 5 0 tensor(0.3492, device='cuda:0') 0.0625
# 5 1 tensor(0.1135, device='cuda:0') 0.1484375
# 5 0 tensor(0.3594, device='cuda:0') 0.046875
# 5 1 tensor(0.1149, device='cuda:0') 0.16015625
# 5 0 tensor(0.3454, device='cuda:0') 0.0546875
# 5 1 tensor(0.1337, device='cuda:0') 0.18359375
# 5 0 tensor(0.3636, device='cuda:0') 0.0546875
# 5 1 tensor(0.0957, device='cuda:0') 0.1171875
# 5 0 tensor(0.3514, device='cuda:0') 0.03125
# 5 1 tensor(0.0934, device='cuda:0') 0.125
# 5 0 tensor(0.3526, device='cuda:0') 0.03125
# 5 1 tensor(0.1005, device='cuda:0') 0.1484375
# 5 0 tensor(0.3478, device='cuda:0') 0.0546875
# 5 1 tensor(0.1083, device='cuda:0') 0.12890625
# 5 0 tensor(0.3322, device='cuda:0') 0.0390625
# 5 1 tensor(0.0994, device='cuda:0') 0.15234375
# 5 0 tensor(0.3477, device='cuda:0') 0.0703125
# 5 1 tensor(0.1292, device='cuda:0') 0.1953125
# 5 0 tensor(0.3179, device='cuda:0') 0.125
# 5 1 tensor(0.1203, device='cuda:0') 0.1640625
# 5 0 tensor(0.3174, device='cuda:0') 0.078125
# 5 1 tensor(0.1552, device='cuda:0') 0.21875
# 6 1 tensor(0.1343, device='cuda:0') 0.19140625
# 6 0 tensor(0.3172, device='cuda:0') 0.0859375
# 6 1 tensor(0.1264, device='cuda:0') 0.171875
# 6 0 tensor(0.3064, device='cuda:0') 0.1328125
# 6 1 tensor(0.1453, device='cuda:0') 0.21484375
# 6 0 tensor(0.3085, device='cuda:0') 0.078125
# 6 1 tensor(0.1795, device='cuda:0') 0.2578125
# 6 0 tensor(0.2799, device='cuda:0') 0.125
# 6 1 tensor(0.1808, device='cuda:0') 0.28515625
# 6 0 tensor(0.2770, device='cuda:0') 0.140625
# 6 1 tensor(0.1808, device='cuda:0') 0.25
# 6 0 tensor(0.2730, device='cuda:0') 0.1484375
# 6 1 tensor(0.1885, device='cuda:0') 0.26953125
# 6 0 tensor(0.2510, device='cuda:0') 0.2265625
# 6 1 tensor(0.2011, device='cuda:0') 0.296875
# 6 0 tensor(0.2994, device='cuda:0') 0.078125
# 6 1 tensor(0.1641, device='cuda:0') 0.23828125
# 6 0 tensor(0.2977, device='cuda:0') 0.1015625
# 6 1 tensor(0.1845, device='cuda:0') 0.2421875
# 6 0 tensor(0.2789, device='cuda:0') 0.1328125
# 6 1 tensor(0.1820, device='cuda:0') 0.265625
# 6 0 tensor(0.2859, device='cuda:0') 0.109375
# 6 1 tensor(0.1645, device='cuda:0') 0.23828125
# 6 0 tensor(0.3147, device='cuda:0') 0.03125
# 6 1 tensor(0.1889, device='cuda:0') 0.2890625
# 6 0 tensor(0.2920, device='cuda:0') 0.109375
# 6 1 tensor(0.1549, device='cuda:0') 0.24609375
# 6 0 tensor(0.3122, device='cuda:0') 0.046875
# 6 1 tensor(0.1352, device='cuda:0') 0.1796875
# 6 0 tensor(0.3263, device='cuda:0') 0.0546875
# 6 1 tensor(0.1599, device='cuda:0') 0.23046875
# 6 0 tensor(0.3289, device='cuda:0') 0.0546875
# 6 1 tensor(0.1163, device='cuda:0') 0.16796875
# 6 0 tensor(0.3393, device='cuda:0') 0.015625
# 6 1 tensor(0.1107, device='cuda:0') 0.12890625
# 6 0 tensor(0.3524, device='cuda:0') 0.0078125
# 6 1 tensor(0.1160, device='cuda:0') 0.15625
# 6 0 tensor(0.3716, device='cuda:0') 0.0
# 6 1 tensor(0.0991, device='cuda:0') 0.125
# 6 0 tensor(0.3766, device='cuda:0') 0.0
# 6 1 tensor(0.1024, device='cuda:0') 0.13671875
# 6 0 tensor(0.3712, device='cuda:0') 0.0
# 6 1 tensor(0.1061, device='cuda:0') 0.12890625
# 6 0 tensor(0.3886, device='cuda:0') 0.0
# 7 0 tensor(0.3813, device='cuda:0') 0.0
# 7 1 tensor(0.1173, device='cuda:0') 0.14453125
# 7 0 tensor(0.3846, device='cuda:0') 0.0
# 7 1 tensor(0.1091, device='cuda:0') 0.14453125
# 7 0 tensor(0.3866, device='cuda:0') 0.0
# 7 1 tensor(0.0892, device='cuda:0') 0.1015625
# 7 0 tensor(0.3980, device='cuda:0') 0.0078125
# 7 1 tensor(0.0984, device='cuda:0') 0.109375
# 7 0 tensor(0.3999, device='cuda:0') 0.0
# 7 1 tensor(0.0820, device='cuda:0') 0.10546875
# 7 0 tensor(0.4093, device='cuda:0') 0.0
# 7 1 tensor(0.1064, device='cuda:0') 0.1484375
# 7 0 tensor(0.4073, device='cuda:0') 0.0
# 7 1 tensor(0.0873, device='cuda:0') 0.1171875
# 7 0 tensor(0.3950, device='cuda:0') 0.0
# 7 1 tensor(0.0958, device='cuda:0') 0.12890625
# 7 0 tensor(0.4007, device='cuda:0') 0.0
# 7 1 tensor(0.0873, device='cuda:0') 0.11328125
# 7 0 tensor(0.4053, device='cuda:0') 0.0
# 7 1 tensor(0.1088, device='cuda:0') 0.140625
# 7 0 tensor(0.4069, device='cuda:0') 0.0
# 7 1 tensor(0.1125, device='cuda:0') 0.13671875
# 7 0 tensor(0.4000, device='cuda:0') 0.0
# 7 1 tensor(0.1087, device='cuda:0') 0.14453125
# 7 0 tensor(0.3907, device='cuda:0') 0.0
# 7 1 tensor(0.1109, device='cuda:0') 0.140625
# 7 0 tensor(0.4085, device='cuda:0') 0.0078125
# 7 1 tensor(0.1195, device='cuda:0') 0.14453125
# 7 0 tensor(0.3960, device='cuda:0') 0.0
# 7 1 tensor(0.1328, device='cuda:0') 0.17578125
# 7 0 tensor(0.3885, device='cuda:0') 0.0
# 7 1 tensor(0.1204, device='cuda:0') 0.13671875
# 7 0 tensor(0.3844, device='cuda:0') 0.015625
# 7 1 tensor(0.1357, device='cuda:0') 0.1796875
# 7 0 tensor(0.3827, device='cuda:0') 0.0078125
# 7 1 tensor(0.1375, device='cuda:0') 0.19921875
# 7 0 tensor(0.3855, device='cuda:0') 0.0
# 7 1 tensor(0.1349, device='cuda:0') 0.17578125
# 7 0 tensor(0.3679, device='cuda:0') 0.03125
# 7 1 tensor(0.1224, device='cuda:0') 0.15625
# 7 0 tensor(0.3603, device='cuda:0') 0.0234375
# 7 1 tensor(0.1451, device='cuda:0') 0.23046875
# 7 0 tensor(0.3636, device='cuda:0') 0.0078125
# 7 1 tensor(0.1358, device='cuda:0') 0.1796875
# 8 1 tensor(0.1468, device='cuda:0') 0.1875
# 8 0 tensor(0.3524, device='cuda:0') 0.0703125
# 8 1 tensor(0.1654, device='cuda:0') 0.21875
# 8 0 tensor(0.3415, device='cuda:0') 0.015625
# 8 1 tensor(0.1477, device='cuda:0') 0.20703125
# 8 0 tensor(0.3461, device='cuda:0') 0.0
# 8 1 tensor(0.1854, device='cuda:0') 0.25390625
# 8 0 tensor(0.3353, device='cuda:0') 0.03125
# 8 1 tensor(0.1700, device='cuda:0') 0.2421875
# 8 0 tensor(0.3345, device='cuda:0') 0.03125
# 8 1 tensor(0.1317, device='cuda:0') 0.1796875
# 8 0 tensor(0.3266, device='cuda:0') 0.0078125
# 8 1 tensor(0.1934, device='cuda:0') 0.3046875
# 8 0 tensor(0.2998, device='cuda:0') 0.0546875
# 8 1 tensor(0.2088, device='cuda:0') 0.296875
# 8 0 tensor(0.2923, device='cuda:0') 0.046875
# 8 1 tensor(0.2207, device='cuda:0') 0.30078125
# 8 0 tensor(0.3055, device='cuda:0') 0.03125
# 8 1 tensor(0.1680, device='cuda:0') 0.22265625
# 8 0 tensor(0.3156, device='cuda:0') 0.0078125
# 8 1 tensor(0.2013, device='cuda:0') 0.26171875
# 8 0 tensor(0.3090, device='cuda:0') 0.03125
# 8 1 tensor(0.2229, device='cuda:0') 0.296875
# 8 0 tensor(0.3152, device='cuda:0') 0.015625
# 8 1 tensor(0.2112, device='cuda:0') 0.29296875
# 8 0 tensor(0.3448, device='cuda:0') 0.0234375
# 8 1 tensor(0.1874, device='cuda:0') 0.2578125
# 8 0 tensor(0.3398, device='cuda:0') 0.0
# 8 1 tensor(0.2043, device='cuda:0') 0.2890625
# 8 0 tensor(0.3442, device='cuda:0') 0.0078125
# 8 1 tensor(0.1964, device='cuda:0') 0.26171875
# 8 0 tensor(0.3537, device='cuda:0') 0.03125
# 8 1 tensor(0.1741, device='cuda:0') 0.23046875
# 8 0 tensor(0.3623, device='cuda:0') 0.0234375
# 8 1 tensor(0.1932, device='cuda:0') 0.26953125
# 8 0 tensor(0.3708, device='cuda:0') 0.0
# 8 1 tensor(0.1783, device='cuda:0') 0.25390625
# 8 0 tensor(0.3799, device='cuda:0') 0.0078125
# 8 1 tensor(0.1732, device='cuda:0') 0.25390625
# 8 0 tensor(0.3730, device='cuda:0') 0.015625
# 8 1 tensor(0.1596, device='cuda:0') 0.20703125
# 8 0 tensor(0.3745, device='cuda:0') 0.0234375
# 8 1 tensor(0.1461, device='cuda:0') 0.17578125
# 8 0 tensor(0.3844, device='cuda:0') 0.0078125
# 9 0 tensor(0.3581, device='cuda:0') 0.03125
# 9 1 tensor(0.1359, device='cuda:0') 0.19921875
# 9 0 tensor(0.3804, device='cuda:0') 0.015625
# 9 1 tensor(0.1288, device='cuda:0') 0.1875
# 9 0 tensor(0.3633, device='cuda:0') 0.0390625
# 9 1 tensor(0.1179, device='cuda:0') 0.1640625
# 9 0 tensor(0.3657, device='cuda:0') 0.0078125
# 9 1 tensor(0.1161, device='cuda:0') 0.16015625
# 9 0 tensor(0.3803, device='cuda:0') 0.03125
# 9 1 tensor(0.1074, device='cuda:0') 0.15234375
# 9 0 tensor(0.3816, device='cuda:0') 0.015625
# 9 1 tensor(0.0981, device='cuda:0') 0.12890625
# 9 0 tensor(0.3814, device='cuda:0') 0.03125
# 9 1 tensor(0.0952, device='cuda:0') 0.13671875
# 9 0 tensor(0.3928, device='cuda:0') 0.0
# 9 1 tensor(0.0920, device='cuda:0') 0.14453125
# 9 0 tensor(0.3814, device='cuda:0') 0.03125
# 9 1 tensor(0.0962, device='cuda:0') 0.1328125
# 9 0 tensor(0.3890, device='cuda:0') 0.015625
# 9 1 tensor(0.0899, device='cuda:0') 0.10546875
# 9 0 tensor(0.3976, device='cuda:0') 0.0078125
# 9 1 tensor(0.0719, device='cuda:0') 0.08203125
# 9 0 tensor(0.3986, device='cuda:0') 0.0390625
# 9 1 tensor(0.0842, device='cuda:0') 0.12109375
# 9 0 tensor(0.3899, device='cuda:0') 0.0234375
# 9 1 tensor(0.0583, device='cuda:0') 0.05859375
# 9 0 tensor(0.3947, device='cuda:0') 0.0234375
# 9 1 tensor(0.0560, device='cuda:0') 0.0625
# 9 0 tensor(0.4065, device='cuda:0') 0.0078125
# 9 1 tensor(0.0585, device='cuda:0') 0.0703125
# 9 0 tensor(0.4038, device='cuda:0') 0.015625
# 9 1 tensor(0.0623, device='cuda:0') 0.07421875
# 9 0 tensor(0.4003, device='cuda:0') 0.0234375
# 9 1 tensor(0.0810, device='cuda:0') 0.1171875
# 9 0 tensor(0.4106, device='cuda:0') 0.0234375
# 9 1 tensor(0.0862, device='cuda:0') 0.1328125
# 9 0 tensor(0.3963, device='cuda:0') 0.015625
# 9 1 tensor(0.0704, device='cuda:0') 0.1171875
# 9 0 tensor(0.3966, device='cuda:0') 0.015625
# 9 1 tensor(0.0735, device='cuda:0') 0.1015625
# 9 0 tensor(0.3879, device='cuda:0') 0.0390625
# 9 1 tensor(0.0619, device='cuda:0') 0.08203125
# 9 0 tensor(0.3958, device='cuda:0') 0.0
# 9 1 tensor(0.0757, device='cuda:0') 0.08203125
# 10 1 tensor(0.0847, device='cuda:0') 0.11328125
# 10 0 tensor(0.3847, device='cuda:0') 0.0234375
# 10 1 tensor(0.0846, device='cuda:0') 0.11328125
# 10 0 tensor(0.3830, device='cuda:0') 0.0390625
# 10 1 tensor(0.0757, device='cuda:0') 0.08984375
# 10 0 tensor(0.3647, device='cuda:0') 0.03125
# 10 1 tensor(0.0784, device='cuda:0') 0.09765625
# 10 0 tensor(0.3438, device='cuda:0') 0.0390625
# 10 1 tensor(0.0956, device='cuda:0') 0.11328125
# 10 0 tensor(0.3282, device='cuda:0') 0.078125
# 10 1 tensor(0.1182, device='cuda:0') 0.15625
# 10 0 tensor(0.3201, device='cuda:0') 0.0546875
# 10 1 tensor(0.1362, device='cuda:0') 0.20703125
# 10 0 tensor(0.3306, device='cuda:0') 0.0625
# 10 1 tensor(0.1147, device='cuda:0') 0.12890625
# 10 0 tensor(0.3184, device='cuda:0') 0.0703125
# 10 1 tensor(0.1148, device='cuda:0') 0.17578125
# 10 0 tensor(0.3241, device='cuda:0') 0.0625
# 10 1 tensor(0.1100, device='cuda:0') 0.1484375
# 10 0 tensor(0.3302, device='cuda:0') 0.0390625
# 10 1 tensor(0.0981, device='cuda:0') 0.125
# 10 0 tensor(0.3348, device='cuda:0') 0.0625
# 10 1 tensor(0.1283, device='cuda:0') 0.1796875
# 10 0 tensor(0.3452, device='cuda:0') 0.0234375
# 10 1 tensor(0.1089, device='cuda:0') 0.15625
# 10 0 tensor(0.3501, device='cuda:0') 0.0234375
# 10 1 tensor(0.1100, device='cuda:0') 0.15234375
# 10 0 tensor(0.3638, device='cuda:0') 0.03125
# 10 1 tensor(0.1275, device='cuda:0') 0.19921875
# 10 0 tensor(0.3495, device='cuda:0') 0.046875
# 10 1 tensor(0.1455, device='cuda:0') 0.2109375
# 10 0 tensor(0.3611, device='cuda:0') 0.0625
# 10 1 tensor(0.1123, device='cuda:0') 0.140625
# 10 0 tensor(0.3524, device='cuda:0') 0.0234375
# 10 1 tensor(0.1240, device='cuda:0') 0.1796875
# 10 0 tensor(0.3510, device='cuda:0') 0.0234375
# 10 1 tensor(0.1294, device='cuda:0') 0.18359375
# 10 0 tensor(0.3504, device='cuda:0') 0.0390625
# 10 1 tensor(0.1338, device='cuda:0') 0.1875
# 10 0 tensor(0.3554, device='cuda:0') 0.0390625
# 10 1 tensor(0.1231, device='cuda:0') 0.18359375
# 10 0 tensor(0.3604, device='cuda:0') 0.0390625
# 10 1 tensor(0.1239, device='cuda:0') 0.16015625
# 10 0 tensor(0.3600, device='cuda:0') 0.03125
# 11 0 tensor(0.3569, device='cuda:0') 0.046875
# 11 1 tensor(0.1224, device='cuda:0') 0.15625
# 11 0 tensor(0.3572, device='cuda:0') 0.03125
# 11 1 tensor(0.1494, device='cuda:0') 0.203125
# 11 0 tensor(0.3434, device='cuda:0') 0.046875
# 11 1 tensor(0.1267, device='cuda:0') 0.15625
# 11 0 tensor(0.3467, device='cuda:0') 0.0546875
# 11 1 tensor(0.1100, device='cuda:0') 0.1484375
# 11 0 tensor(0.3306, device='cuda:0') 0.0625
# 11 1 tensor(0.1489, device='cuda:0') 0.21875
# 11 0 tensor(0.3406, device='cuda:0') 0.046875
# 11 1 tensor(0.1508, device='cuda:0') 0.22265625
# 11 0 tensor(0.3449, device='cuda:0') 0.0390625
# 11 1 tensor(0.1552, device='cuda:0') 0.21484375
# 11 0 tensor(0.3359, device='cuda:0') 0.078125
# 11 1 tensor(0.1244, device='cuda:0') 0.16796875
# 11 0 tensor(0.3443, device='cuda:0') 0.078125
# 11 1 tensor(0.1417, device='cuda:0') 0.18359375
# 11 0 tensor(0.3322, device='cuda:0') 0.1015625
# 11 1 tensor(0.1674, device='cuda:0') 0.203125
# 11 0 tensor(0.3541, device='cuda:0') 0.0546875
# 11 1 tensor(0.1589, device='cuda:0') 0.234375
# 11 0 tensor(0.3311, device='cuda:0') 0.0546875
# 11 1 tensor(0.1478, device='cuda:0') 0.1875
# 11 0 tensor(0.3388, device='cuda:0') 0.078125
# 11 1 tensor(0.0956, device='cuda:0') 0.12109375
# 11 0 tensor(0.3550, device='cuda:0') 0.03125
# 11 1 tensor(0.1324, device='cuda:0') 0.16796875
# 11 0 tensor(0.3531, device='cuda:0') 0.0703125
# 11 1 tensor(0.1411, device='cuda:0') 0.1875
# 11 0 tensor(0.3413, device='cuda:0') 0.0703125
# 11 1 tensor(0.1410, device='cuda:0') 0.1875
# 11 0 tensor(0.3468, device='cuda:0') 0.0390625
# 11 1 tensor(0.1662, device='cuda:0') 0.21875
# 11 0 tensor(0.3481, device='cuda:0') 0.0625
# 11 1 tensor(0.1553, device='cuda:0') 0.21875
# 11 0 tensor(0.3452, device='cuda:0') 0.0546875
# 11 1 tensor(0.1326, device='cuda:0') 0.1796875
# 11 0 tensor(0.3319, device='cuda:0') 0.046875
# 11 1 tensor(0.1539, device='cuda:0') 0.2109375
# 11 0 tensor(0.3415, device='cuda:0') 0.0390625
# 11 1 tensor(0.1612, device='cuda:0') 0.22265625
# 11 0 tensor(0.3299, device='cuda:0') 0.078125
# 11 1 tensor(0.1574, device='cuda:0') 0.23046875
# 12 1 tensor(0.1792, device='cuda:0') 0.25390625
# 12 0 tensor(0.3501, device='cuda:0') 0.0546875
# 12 1 tensor(0.1591, device='cuda:0') 0.21484375
# 12 0 tensor(0.3405, device='cuda:0') 0.0703125
# 12 1 tensor(0.1569, device='cuda:0') 0.203125
# 12 0 tensor(0.3342, device='cuda:0') 0.078125
# 12 1 tensor(0.1957, device='cuda:0') 0.29296875
# 12 0 tensor(0.3322, device='cuda:0') 0.0625
# 12 1 tensor(0.1706, device='cuda:0') 0.23828125
# 12 0 tensor(0.3324, device='cuda:0') 0.0390625
# 12 1 tensor(0.1497, device='cuda:0') 0.1953125
# 12 0 tensor(0.3386, device='cuda:0') 0.0703125
# 12 1 tensor(0.1550, device='cuda:0') 0.2109375
# 12 0 tensor(0.3535, device='cuda:0') 0.0625
# 12 1 tensor(0.1581, device='cuda:0') 0.2109375
# 12 0 tensor(0.3526, device='cuda:0') 0.0390625
# 12 1 tensor(0.1507, device='cuda:0') 0.21875
# 12 0 tensor(0.3661, device='cuda:0') 0.0234375
# 12 1 tensor(0.1561, device='cuda:0') 0.23046875
# 12 0 tensor(0.3734, device='cuda:0') 0.03125
# 12 1 tensor(0.1496, device='cuda:0') 0.19921875
# 12 0 tensor(0.3701, device='cuda:0') 0.0078125
# 12 1 tensor(0.1543, device='cuda:0') 0.20703125
# 12 0 tensor(0.3958, device='cuda:0') 0.0078125
# 12 1 tensor(0.1630, device='cuda:0') 0.24609375
# 12 0 tensor(0.3706, device='cuda:0') 0.0234375
# 12 1 tensor(0.1511, device='cuda:0') 0.23046875
# 12 0 tensor(0.3820, device='cuda:0') 0.0078125
# 12 1 tensor(0.1569, device='cuda:0') 0.21875
# 12 0 tensor(0.3671, device='cuda:0') 0.015625
# 12 1 tensor(0.1247, device='cuda:0') 0.1640625
# 12 0 tensor(0.3682, device='cuda:0') 0.0078125
# 12 1 tensor(0.1426, device='cuda:0') 0.1953125
# 12 0 tensor(0.3687, device='cuda:0') 0.03125
# 12 1 tensor(0.1324, device='cuda:0') 0.171875
# 12 0 tensor(0.3545, device='cuda:0') 0.0390625
# 12 1 tensor(0.1240, device='cuda:0') 0.171875
# 12 0 tensor(0.3588, device='cuda:0') 0.0234375
# 12 1 tensor(0.1330, device='cuda:0') 0.1953125
# 12 0 tensor(0.3495, device='cuda:0') 0.0234375
# 12 1 tensor(0.1163, device='cuda:0') 0.14453125
# 12 0 tensor(0.3454, device='cuda:0') 0.03125
# 12 1 tensor(0.1471, device='cuda:0') 0.2109375
# 12 0 tensor(0.3227, device='cuda:0') 0.0546875
# 13 0 tensor(0.3224, device='cuda:0') 0.078125
# 13 1 tensor(0.1157, device='cuda:0') 0.16796875
# 13 0 tensor(0.3282, device='cuda:0') 0.0859375
# 13 1 tensor(0.1568, device='cuda:0') 0.21484375
# 13 0 tensor(0.3237, device='cuda:0') 0.0703125
# 13 1 tensor(0.1318, device='cuda:0') 0.19140625
# 13 0 tensor(0.3084, device='cuda:0') 0.078125
# 13 1 tensor(0.1539, device='cuda:0') 0.203125
# 13 0 tensor(0.3116, device='cuda:0') 0.078125
# 13 1 tensor(0.1561, device='cuda:0') 0.2109375
# 13 0 tensor(0.2973, device='cuda:0') 0.0859375
# 13 1 tensor(0.1729, device='cuda:0') 0.26171875
# 13 0 tensor(0.3168, device='cuda:0') 0.0625
# 13 1 tensor(0.1701, device='cuda:0') 0.234375
# 13 0 tensor(0.3087, device='cuda:0') 0.0859375
# 13 1 tensor(0.1920, device='cuda:0') 0.265625
# 13 0 tensor(0.2991, device='cuda:0') 0.1171875
# 13 1 tensor(0.1755, device='cuda:0') 0.25390625
# 13 0 tensor(0.3070, device='cuda:0') 0.125
# 13 1 tensor(0.1984, device='cuda:0') 0.3046875
# 13 0 tensor(0.2940, device='cuda:0') 0.15625
# 13 1 tensor(0.2064, device='cuda:0') 0.3046875
# 13 0 tensor(0.3024, device='cuda:0') 0.109375
# 13 1 tensor(0.2020, device='cuda:0') 0.28515625
# 13 0 tensor(0.3078, device='cuda:0') 0.0859375
# 13 1 tensor(0.2173, device='cuda:0') 0.3203125
# 13 0 tensor(0.2928, device='cuda:0') 0.1171875
# 13 1 tensor(0.2137, device='cuda:0') 0.3046875
# 13 0 tensor(0.3202, device='cuda:0') 0.0703125
# 13 1 tensor(0.1977, device='cuda:0') 0.2734375
# 13 0 tensor(0.3204, device='cuda:0') 0.078125
# 13 1 tensor(0.2162, device='cuda:0') 0.3046875
# 13 0 tensor(0.3254, device='cuda:0') 0.0546875
# 13 1 tensor(0.2168, device='cuda:0') 0.296875
# 13 0 tensor(0.3130, device='cuda:0') 0.1015625
# 13 1 tensor(0.2070, device='cuda:0') 0.29296875
# 13 0 tensor(0.3225, device='cuda:0') 0.0625
# 13 1 tensor(0.1963, device='cuda:0') 0.27734375
# 13 0 tensor(0.3126, device='cuda:0') 0.1015625
# 13 1 tensor(0.1785, device='cuda:0') 0.2734375
# 13 0 tensor(0.3112, device='cuda:0') 0.078125
# 13 1 tensor(0.1524, device='cuda:0') 0.20703125
# 13 0 tensor(0.3380, device='cuda:0') 0.0625
# 13 1 tensor(0.1538, device='cuda:0') 0.234375
# 14 1 tensor(0.1454, device='cuda:0') 0.19921875
# 14 0 tensor(0.3528, device='cuda:0') 0.0625
# 14 1 tensor(0.1067, device='cuda:0') 0.16015625
# 14 0 tensor(0.3717, device='cuda:0') 0.03125
# 14 1 tensor(0.0916, device='cuda:0') 0.11328125
# 14 0 tensor(0.3646, device='cuda:0') 0.015625
# 14 1 tensor(0.0998, device='cuda:0') 0.12890625
# 14 0 tensor(0.3818, device='cuda:0') 0.0234375
# 14 1 tensor(0.0895, device='cuda:0') 0.1328125
# 14 0 tensor(0.3768, device='cuda:0') 0.03125
# 14 1 tensor(0.0730, device='cuda:0') 0.06640625
# 14 0 tensor(0.3898, device='cuda:0') 0.0078125
# 14 1 tensor(0.0837, device='cuda:0') 0.10546875
# 14 0 tensor(0.3855, device='cuda:0') 0.0234375
# 14 1 tensor(0.0640, device='cuda:0') 0.0703125
# 14 0 tensor(0.3935, device='cuda:0') 0.0234375
# 14 1 tensor(0.0704, device='cuda:0') 0.08203125
# 14 0 tensor(0.3800, device='cuda:0') 0.015625
# 14 1 tensor(0.0768, device='cuda:0') 0.08203125
# 14 0 tensor(0.3764, device='cuda:0') 0.0234375
# 14 1 tensor(0.0811, device='cuda:0') 0.09765625
# 14 0 tensor(0.3688, device='cuda:0') 0.0390625
# 14 1 tensor(0.0633, device='cuda:0') 0.0703125
# 14 0 tensor(0.3592, device='cuda:0') 0.046875
# 14 1 tensor(0.0945, device='cuda:0') 0.1171875
# 14 0 tensor(0.3568, device='cuda:0') 0.0390625
# 14 1 tensor(0.0964, device='cuda:0') 0.1484375
# 14 0 tensor(0.3453, device='cuda:0') 0.0390625
# 14 1 tensor(0.1031, device='cuda:0') 0.14453125
# 14 0 tensor(0.3045, device='cuda:0') 0.1015625
# 14 1 tensor(0.1102, device='cuda:0') 0.1640625
# 14 0 tensor(0.3158, device='cuda:0') 0.078125
# 14 1 tensor(0.1242, device='cuda:0') 0.1953125
# 14 0 tensor(0.3215, device='cuda:0') 0.0703125
# 14 1 tensor(0.1323, device='cuda:0') 0.1796875
# 14 0 tensor(0.3115, device='cuda:0') 0.078125
# 14 1 tensor(0.1425, device='cuda:0') 0.21875
# 14 0 tensor(0.3148, device='cuda:0') 0.0390625
# 14 1 tensor(0.1329, device='cuda:0') 0.18359375
# 14 0 tensor(0.3221, device='cuda:0') 0.0859375
# 14 1 tensor(0.1625, device='cuda:0') 0.234375
# 14 0 tensor(0.3302, device='cuda:0') 0.0234375
# 14 1 tensor(0.1125, device='cuda:0') 0.13671875
# 14 0 tensor(0.3224, device='cuda:0') 0.0703125
# 15 0 tensor(0.3052, device='cuda:0') 0.078125
# 15 1 tensor(0.1476, device='cuda:0') 0.18359375
# 15 0 tensor(0.2995, device='cuda:0') 0.109375
# 15 1 tensor(0.1666, device='cuda:0') 0.23046875
# 15 0 tensor(0.3124, device='cuda:0') 0.078125
# 15 1 tensor(0.1913, device='cuda:0') 0.2734375
# 15 0 tensor(0.3266, device='cuda:0') 0.03125
# 15 1 tensor(0.1743, device='cuda:0') 0.234375
# 15 0 tensor(0.3327, device='cuda:0') 0.0234375
# 15 1 tensor(0.1445, device='cuda:0') 0.171875
# 15 0 tensor(0.3291, device='cuda:0') 0.03125
# 15 1 tensor(0.1826, device='cuda:0') 0.21484375
# 15 0 tensor(0.3554, device='cuda:0') 0.0078125
# 15 1 tensor(0.1968, device='cuda:0') 0.25
# 15 0 tensor(0.3342, device='cuda:0') 0.0
# 15 1 tensor(0.1931, device='cuda:0') 0.25390625
# 15 0 tensor(0.3385, device='cuda:0') 0.015625
# 15 1 tensor(0.1721, device='cuda:0') 0.21484375
# 15 0 tensor(0.3306, device='cuda:0') 0.0078125
# 15 1 tensor(0.1501, device='cuda:0') 0.1953125
# 15 0 tensor(0.3241, device='cuda:0') 0.015625
# 15 1 tensor(0.1980, device='cuda:0') 0.25390625
# 15 0 tensor(0.3221, device='cuda:0') 0.03125
# 15 1 tensor(0.1972, device='cuda:0') 0.27734375
# 15 0 tensor(0.3242, device='cuda:0') 0.03125
# 15 1 tensor(0.2294, device='cuda:0') 0.33203125
# 15 0 tensor(0.3069, device='cuda:0') 0.0703125
# 15 1 tensor(0.1874, device='cuda:0') 0.25390625
# 15 0 tensor(0.3070, device='cuda:0') 0.0390625
# 15 1 tensor(0.1864, device='cuda:0') 0.24609375
# 15 0 tensor(0.3162, device='cuda:0') 0.046875
# 15 1 tensor(0.1840, device='cuda:0') 0.25390625
# 15 0 tensor(0.3174, device='cuda:0') 0.015625
# 15 1 tensor(0.1794, device='cuda:0') 0.25390625
# 15 0 tensor(0.3208, device='cuda:0') 0.0234375
# 15 1 tensor(0.2021, device='cuda:0') 0.2734375
# 15 0 tensor(0.3194, device='cuda:0') 0.03125
# 15 1 tensor(0.1729, device='cuda:0') 0.22265625
# 15 0 tensor(0.3332, device='cuda:0') 0.03125
# 15 1 tensor(0.1511, device='cuda:0') 0.1796875
# 15 0 tensor(0.3365, device='cuda:0') 0.015625
# 15 1 tensor(0.1777, device='cuda:0') 0.26171875
# 15 0 tensor(0.3377, device='cuda:0') 0.0390625
# 15 1 tensor(0.2066, device='cuda:0') 0.28125
# 16 1 tensor(0.1670, device='cuda:0') 0.23828125
# 16 0 tensor(0.3429, device='cuda:0') 0.0078125
# 16 1 tensor(0.1631, device='cuda:0') 0.234375
# 16 0 tensor(0.3587, device='cuda:0') 0.015625
# 16 1 tensor(0.1492, device='cuda:0') 0.19140625
# 16 0 tensor(0.3544, device='cuda:0') 0.0234375
# 16 1 tensor(0.1623, device='cuda:0') 0.21484375
# 16 0 tensor(0.3601, device='cuda:0') 0.0
# 16 1 tensor(0.1591, device='cuda:0') 0.2265625
# 16 0 tensor(0.3501, device='cuda:0') 0.0390625
# 16 1 tensor(0.1635, device='cuda:0') 0.23046875
# 16 0 tensor(0.3545, device='cuda:0') 0.03125
# 16 1 tensor(0.1348, device='cuda:0') 0.17578125
# 16 0 tensor(0.3640, device='cuda:0') 0.015625
# 16 1 tensor(0.1812, device='cuda:0') 0.27734375
# 16 0 tensor(0.3692, device='cuda:0') 0.015625
# 16 1 tensor(0.1368, device='cuda:0') 0.17578125
# 16 0 tensor(0.3523, device='cuda:0') 0.0546875
# 16 1 tensor(0.1815, device='cuda:0') 0.25390625
# 16 0 tensor(0.3499, device='cuda:0') 0.0546875
# 16 1 tensor(0.1837, device='cuda:0') 0.28515625
# 16 0 tensor(0.3568, device='cuda:0') 0.0390625
# 16 1 tensor(0.1378, device='cuda:0') 0.19140625
# 16 0 tensor(0.3589, device='cuda:0') 0.0625
# 16 1 tensor(0.1604, device='cuda:0') 0.21484375
# 16 0 tensor(0.3441, device='cuda:0') 0.0546875
# 16 1 tensor(0.1402, device='cuda:0') 0.2109375
# 16 0 tensor(0.3512, device='cuda:0') 0.0625
# 16 1 tensor(0.1579, device='cuda:0') 0.21875
# 16 0 tensor(0.3573, device='cuda:0') 0.0390625
# 16 1 tensor(0.1432, device='cuda:0') 0.1953125
# 16 0 tensor(0.3490, device='cuda:0') 0.046875
# 16 1 tensor(0.1833, device='cuda:0') 0.265625
# 16 0 tensor(0.3311, device='cuda:0') 0.1015625
# 16 1 tensor(0.1858, device='cuda:0') 0.27734375
# 16 0 tensor(0.3397, device='cuda:0') 0.078125
# 16 1 tensor(0.1719, device='cuda:0') 0.234375
# 16 0 tensor(0.3371, device='cuda:0') 0.09375
# 16 1 tensor(0.1667, device='cuda:0') 0.25
# 16 0 tensor(0.3337, device='cuda:0') 0.0625
# 16 1 tensor(0.1800, device='cuda:0') 0.2578125
# 16 0 tensor(0.3254, device='cuda:0') 0.09375
# 16 1 tensor(0.2126, device='cuda:0') 0.31640625
# 16 0 tensor(0.3151, device='cuda:0') 0.1328125
# 17 0 tensor(0.2927, device='cuda:0') 0.1328125
# 17 1 tensor(0.2066, device='cuda:0') 0.30078125
# 17 0 tensor(0.3006, device='cuda:0') 0.1015625
# 17 1 tensor(0.2079, device='cuda:0') 0.33984375
# 17 0 tensor(0.3029, device='cuda:0') 0.125
# 17 1 tensor(0.1915, device='cuda:0') 0.2734375
# 17 0 tensor(0.3045, device='cuda:0') 0.09375
# 17 1 tensor(0.2124, device='cuda:0') 0.30859375
# 17 0 tensor(0.3095, device='cuda:0') 0.0703125
# 17 1 tensor(0.2382, device='cuda:0') 0.3359375
# 17 0 tensor(0.3281, device='cuda:0') 0.078125
# 17 1 tensor(0.2367, device='cuda:0') 0.359375
# 17 0 tensor(0.3073, device='cuda:0') 0.0859375
# 17 1 tensor(0.2236, device='cuda:0') 0.3125
# 17 0 tensor(0.3073, device='cuda:0') 0.09375
# 17 1 tensor(0.2253, device='cuda:0') 0.3125
# 17 0 tensor(0.2997, device='cuda:0') 0.09375
# 17 1 tensor(0.2100, device='cuda:0') 0.328125
# 17 0 tensor(0.3062, device='cuda:0') 0.0703125
# 17 1 tensor(0.2185, device='cuda:0') 0.3515625
# 17 0 tensor(0.2994, device='cuda:0') 0.0859375
# 17 1 tensor(0.2617, device='cuda:0') 0.40625
# 17 0 tensor(0.2845, device='cuda:0') 0.1171875
# 17 1 tensor(0.2250, device='cuda:0') 0.33203125
# 17 0 tensor(0.3101, device='cuda:0') 0.109375
# 17 1 tensor(0.2264, device='cuda:0') 0.33984375
# 17 0 tensor(0.3109, device='cuda:0') 0.09375
# 17 1 tensor(0.2558, device='cuda:0') 0.3828125
# 17 0 tensor(0.2884, device='cuda:0') 0.1328125
# 17 1 tensor(0.2124, device='cuda:0') 0.3046875
# 17 0 tensor(0.3158, device='cuda:0') 0.09375
# 17 1 tensor(0.1976, device='cuda:0') 0.2578125
# 17 0 tensor(0.3043, device='cuda:0') 0.078125
# 17 1 tensor(0.2057, device='cuda:0') 0.30078125
# 17 0 tensor(0.3087, device='cuda:0') 0.1171875
# 17 1 tensor(0.2152, device='cuda:0') 0.3125
# 17 0 tensor(0.3190, device='cuda:0') 0.0546875
# 17 1 tensor(0.2127, device='cuda:0') 0.32421875
# 17 0 tensor(0.3280, device='cuda:0') 0.0390625
# 17 1 tensor(0.1975, device='cuda:0') 0.28125
# 17 0 tensor(0.3193, device='cuda:0') 0.0546875
# 17 1 tensor(0.1656, device='cuda:0') 0.24609375
# 17 0 tensor(0.3216, device='cuda:0') 0.046875
# 17 1 tensor(0.1488, device='cuda:0') 0.21484375
# 18 1 tensor(0.1329, device='cuda:0') 0.1953125
# 18 0 tensor(0.3596, device='cuda:0') 0.03125
# 18 1 tensor(0.1226, device='cuda:0') 0.1796875
# 18 0 tensor(0.3576, device='cuda:0') 0.015625
# 18 1 tensor(0.1068, device='cuda:0') 0.14453125
# 18 0 tensor(0.3513, device='cuda:0') 0.0234375
# 18 1 tensor(0.1253, device='cuda:0') 0.16796875
# 18 0 tensor(0.3788, device='cuda:0') 0.015625
# 18 1 tensor(0.1122, device='cuda:0') 0.15625
# 18 0 tensor(0.3665, device='cuda:0') 0.03125
# 18 1 tensor(0.0992, device='cuda:0') 0.125
# 18 0 tensor(0.3640, device='cuda:0') 0.0078125
# 18 1 tensor(0.0929, device='cuda:0') 0.109375
# 18 0 tensor(0.3679, device='cuda:0') 0.0078125
# 18 1 tensor(0.1045, device='cuda:0') 0.14453125
# 18 0 tensor(0.3636, device='cuda:0') 0.0234375
# 18 1 tensor(0.0933, device='cuda:0') 0.12890625
# 18 0 tensor(0.3752, device='cuda:0') 0.0234375
# 18 1 tensor(0.1056, device='cuda:0') 0.14453125
# 18 0 tensor(0.3647, device='cuda:0') 0.0234375
# 18 1 tensor(0.0877, device='cuda:0') 0.1171875
# 18 0 tensor(0.3754, device='cuda:0') 0.0078125
# 18 1 tensor(0.0898, device='cuda:0') 0.125
# 18 0 tensor(0.3687, device='cuda:0') 0.015625
# 18 1 tensor(0.0871, device='cuda:0') 0.09375
# 18 0 tensor(0.3783, device='cuda:0') 0.0078125
# 18 1 tensor(0.1134, device='cuda:0') 0.18359375
# 18 0 tensor(0.3667, device='cuda:0') 0.015625
# 18 1 tensor(0.0916, device='cuda:0') 0.125
# 18 0 tensor(0.3710, device='cuda:0') 0.0
# 18 1 tensor(0.0862, device='cuda:0') 0.11328125
# 18 0 tensor(0.3622, device='cuda:0') 0.015625
# 18 1 tensor(0.1104, device='cuda:0') 0.16015625
# 18 0 tensor(0.3447, device='cuda:0') 0.0234375
# 18 1 tensor(0.1315, device='cuda:0') 0.19140625
# 18 0 tensor(0.3434, device='cuda:0') 0.046875
# 18 1 tensor(0.1358, device='cuda:0') 0.18359375
# 18 0 tensor(0.3265, device='cuda:0') 0.03125
# 18 1 tensor(0.1451, device='cuda:0') 0.19921875
# 18 0 tensor(0.3182, device='cuda:0') 0.0234375
# 18 1 tensor(0.1103, device='cuda:0') 0.15234375
# 18 0 tensor(0.3238, device='cuda:0') 0.015625
# 18 1 tensor(0.1488, device='cuda:0') 0.20703125
# 18 0 tensor(0.3126, device='cuda:0') 0.046875
# 19 0 tensor(0.2800, device='cuda:0') 0.0625
# 19 1 tensor(0.1748, device='cuda:0') 0.24609375
# 19 0 tensor(0.2863, device='cuda:0') 0.0859375
# 19 1 tensor(0.1450, device='cuda:0') 0.203125
# 19 0 tensor(0.2737, device='cuda:0') 0.1015625
# 19 1 tensor(0.1745, device='cuda:0') 0.24609375
# 19 0 tensor(0.2836, device='cuda:0') 0.078125
# 19 1 tensor(0.1787, device='cuda:0') 0.26953125
# 19 0 tensor(0.3121, device='cuda:0') 0.0234375
# 19 1 tensor(0.1661, device='cuda:0') 0.24609375
# 19 0 tensor(0.3055, device='cuda:0') 0.0390625
# 19 1 tensor(0.1702, device='cuda:0') 0.22265625
# 19 0 tensor(0.3189, device='cuda:0') 0.0234375
# 19 1 tensor(0.1826, device='cuda:0') 0.24609375
# 19 0 tensor(0.2922, device='cuda:0') 0.0546875
# 19 1 tensor(0.1762, device='cuda:0') 0.25
# 19 0 tensor(0.3082, device='cuda:0') 0.03125
# 19 1 tensor(0.1794, device='cuda:0') 0.21875
# 19 0 tensor(0.3126, device='cuda:0') 0.03125
# 19 1 tensor(0.1977, device='cuda:0') 0.2421875
# 19 0 tensor(0.3079, device='cuda:0') 0.015625
# 19 1 tensor(0.2000, device='cuda:0') 0.2890625
# 19 0 tensor(0.2983, device='cuda:0') 0.0234375
# 19 1 tensor(0.2141, device='cuda:0') 0.27734375
# 19 0 tensor(0.3108, device='cuda:0') 0.015625
# 19 1 tensor(0.1977, device='cuda:0') 0.2578125
# 19 0 tensor(0.3127, device='cuda:0') 0.0234375
# 19 1 tensor(0.1660, device='cuda:0') 0.21875
# 19 0 tensor(0.3083, device='cuda:0') 0.0234375
# 19 1 tensor(0.2110, device='cuda:0') 0.2578125
# 19 0 tensor(0.3025, device='cuda:0') 0.0390625
# 19 1 tensor(0.1865, device='cuda:0') 0.25390625
# 19 0 tensor(0.2984, device='cuda:0') 0.03125
# 19 1 tensor(0.1907, device='cuda:0') 0.24609375
# 19 0 tensor(0.2825, device='cuda:0') 0.0859375
# 19 1 tensor(0.2215, device='cuda:0') 0.28515625
# 19 0 tensor(0.3031, device='cuda:0') 0.0390625
# 19 1 tensor(0.1845, device='cuda:0') 0.25390625
# 19 0 tensor(0.3064, device='cuda:0') 0.0625
# 19 1 tensor(0.2125, device='cuda:0') 0.26171875
# 19 0 tensor(0.2930, device='cuda:0') 0.046875
# 19 1 tensor(0.2307, device='cuda:0') 0.3046875
# 19 0 tensor(0.3245, device='cuda:0') 0.0390625
# 19 1 tensor(0.2410, device='cuda:0') 0.3359375
# 20 1 tensor(0.2096, device='cuda:0') 0.265625
# 20 0 tensor(0.3493, device='cuda:0') 0.0078125
# 20 1 tensor(0.2285, device='cuda:0') 0.3125
# 20 0 tensor(0.3583, device='cuda:0') 0.0078125
# 20 1 tensor(0.1908, device='cuda:0') 0.24609375
# 20 0 tensor(0.3601, device='cuda:0') 0.015625
# 20 1 tensor(0.2449, device='cuda:0') 0.3125
# 20 0 tensor(0.3574, device='cuda:0') 0.0390625
# 20 1 tensor(0.2402, device='cuda:0') 0.30859375
# 20 0 tensor(0.3698, device='cuda:0') 0.0078125
# 20 1 tensor(0.2526, device='cuda:0') 0.34765625
# 20 0 tensor(0.3716, device='cuda:0') 0.015625
# 20 1 tensor(0.2672, device='cuda:0') 0.34375
# 20 0 tensor(0.3749, device='cuda:0') 0.0
# 20 1 tensor(0.2527, device='cuda:0') 0.32421875
# 20 0 tensor(0.3852, device='cuda:0') 0.0
# 20 1 tensor(0.2288, device='cuda:0') 0.27734375
# 20 0 tensor(0.3691, device='cuda:0') 0.015625
# 20 1 tensor(0.2242, device='cuda:0') 0.2734375
# 20 0 tensor(0.3812, device='cuda:0') 0.015625
# 20 1 tensor(0.2441, device='cuda:0') 0.296875
# 20 0 tensor(0.3897, device='cuda:0') 0.0078125
# 20 1 tensor(0.2259, device='cuda:0') 0.2890625
# 20 0 tensor(0.3931, device='cuda:0') 0.0078125
# 20 1 tensor(0.2263, device='cuda:0') 0.265625
# 20 0 tensor(0.3969, device='cuda:0') 0.0
# 20 1 tensor(0.2092, device='cuda:0') 0.2578125
# 20 0 tensor(0.3986, device='cuda:0') 0.015625
# 20 1 tensor(0.2243, device='cuda:0') 0.26171875
# 20 0 tensor(0.3975, device='cuda:0') 0.015625
# 20 1 tensor(0.2308, device='cuda:0') 0.3125
# 20 0 tensor(0.3982, device='cuda:0') 0.0
# 20 1 tensor(0.1867, device='cuda:0') 0.23828125
# 20 0 tensor(0.3899, device='cuda:0') 0.0234375
# 20 1 tensor(0.2248, device='cuda:0') 0.28515625
# 20 0 tensor(0.3997, device='cuda:0') 0.0
# 20 1 tensor(0.2170, device='cuda:0') 0.3046875
# 20 0 tensor(0.3967, device='cuda:0') 0.0
# 20 1 tensor(0.2385, device='cuda:0') 0.3046875
# 20 0 tensor(0.3939, device='cuda:0') 0.0
# 20 1 tensor(0.2159, device='cuda:0') 0.28515625
# 20 0 tensor(0.3992, device='cuda:0') 0.0078125
# 20 1 tensor(0.2322, device='cuda:0') 0.3125
# 20 0 tensor(0.3927, device='cuda:0') 0.0078125
# 21 0 tensor(0.3711, device='cuda:0') 0.015625
# 21 1 tensor(0.2316, device='cuda:0') 0.3046875
# 21 0 tensor(0.3707, device='cuda:0') 0.015625
# 21 1 tensor(0.1611, device='cuda:0') 0.2109375
# 21 0 tensor(0.3843, device='cuda:0') 0.0
# 21 1 tensor(0.2023, device='cuda:0') 0.23046875
# 21 0 tensor(0.3684, device='cuda:0') 0.015625
# 21 1 tensor(0.1911, device='cuda:0') 0.2421875
# 21 0 tensor(0.3704, device='cuda:0') 0.015625
# 21 1 tensor(0.1806, device='cuda:0') 0.23046875
# 21 0 tensor(0.3744, device='cuda:0') 0.03125
# 21 1 tensor(0.1793, device='cuda:0') 0.234375
# 21 0 tensor(0.3694, device='cuda:0') 0.0234375
# 21 1 tensor(0.1805, device='cuda:0') 0.2265625
# 21 0 tensor(0.3816, device='cuda:0') 0.0078125
# 21 1 tensor(0.1803, device='cuda:0') 0.23828125
# 21 0 tensor(0.3913, device='cuda:0') 0.0078125
# 21 1 tensor(0.1459, device='cuda:0') 0.203125
# 21 0 tensor(0.3882, device='cuda:0') 0.0234375
# 21 1 tensor(0.1376, device='cuda:0') 0.16796875
# 21 0 tensor(0.3835, device='cuda:0') 0.0078125
# 21 1 tensor(0.1400, device='cuda:0') 0.171875
# 21 0 tensor(0.3770, device='cuda:0') 0.0
# 21 1 tensor(0.1196, device='cuda:0') 0.171875
# 21 0 tensor(0.3890, device='cuda:0') 0.0
# 21 1 tensor(0.1472, device='cuda:0') 0.20703125
# 21 0 tensor(0.3901, device='cuda:0') 0.0
# 21 1 tensor(0.1372, device='cuda:0') 0.19921875
# 21 0 tensor(0.3901, device='cuda:0') 0.0078125
# 21 1 tensor(0.1186, device='cuda:0') 0.16015625
# 21 0 tensor(0.3750, device='cuda:0') 0.0234375
# 21 1 tensor(0.1230, device='cuda:0') 0.17578125
# 21 0 tensor(0.3697, device='cuda:0') 0.03125
# 21 1 tensor(0.1184, device='cuda:0') 0.16796875
# 21 0 tensor(0.3781, device='cuda:0') 0.0234375
# 21 1 tensor(0.1405, device='cuda:0') 0.203125
# 21 0 tensor(0.3633, device='cuda:0') 0.046875
# 21 1 tensor(0.1178, device='cuda:0') 0.15234375
# 21 0 tensor(0.3535, device='cuda:0') 0.0390625
# 21 1 tensor(0.1366, device='cuda:0') 0.1953125
# 21 0 tensor(0.3669, device='cuda:0') 0.0390625
# 21 1 tensor(0.1276, device='cuda:0') 0.19140625
# 21 0 tensor(0.3797, device='cuda:0') 0.0390625
# 21 1 tensor(0.1364, device='cuda:0') 0.19140625
# 22 1 tensor(0.1276, device='cuda:0') 0.1875
# 22 0 tensor(0.3820, device='cuda:0') 0.0078125
# 22 1 tensor(0.1001, device='cuda:0') 0.1484375
# 22 0 tensor(0.3813, device='cuda:0') 0.03125
# 22 1 tensor(0.1290, device='cuda:0') 0.16796875
# 22 0 tensor(0.3863, device='cuda:0') 0.015625
# 22 1 tensor(0.1398, device='cuda:0') 0.1875
# 22 0 tensor(0.3883, device='cuda:0') 0.03125
# 22 1 tensor(0.1046, device='cuda:0') 0.1484375
# 22 0 tensor(0.3891, device='cuda:0') 0.0234375
# 22 1 tensor(0.1441, device='cuda:0') 0.19140625
# 22 0 tensor(0.3872, device='cuda:0') 0.0234375
# 22 1 tensor(0.1204, device='cuda:0') 0.15625
# 22 0 tensor(0.3903, device='cuda:0') 0.0234375
# 22 1 tensor(0.1162, device='cuda:0') 0.15625
# 22 0 tensor(0.3930, device='cuda:0') 0.015625
# 22 1 tensor(0.1073, device='cuda:0') 0.14453125
# 22 0 tensor(0.3868, device='cuda:0') 0.03125
# 22 1 tensor(0.1533, device='cuda:0') 0.2109375
# 22 0 tensor(0.3909, device='cuda:0') 0.0078125
# 22 1 tensor(0.1285, device='cuda:0') 0.1953125
# 22 0 tensor(0.3994, device='cuda:0') 0.0078125
# 22 1 tensor(0.1462, device='cuda:0') 0.1875
# 22 0 tensor(0.3837, device='cuda:0') 0.0546875
# 22 1 tensor(0.1210, device='cuda:0') 0.15625
# 22 0 tensor(0.3877, device='cuda:0') 0.0234375
# 22 1 tensor(0.1255, device='cuda:0') 0.17578125
# 22 0 tensor(0.3903, device='cuda:0') 0.0390625
# 22 1 tensor(0.1618, device='cuda:0') 0.2265625
# 22 0 tensor(0.3770, device='cuda:0') 0.046875
# 22 1 tensor(0.1562, device='cuda:0') 0.21875
# 22 0 tensor(0.3814, device='cuda:0') 0.03125
# 22 1 tensor(0.1568, device='cuda:0') 0.2109375
# 22 0 tensor(0.3966, device='cuda:0') 0.03125
# 22 1 tensor(0.1905, device='cuda:0') 0.26953125
# 22 0 tensor(0.3815, device='cuda:0') 0.0390625
# 22 1 tensor(0.1711, device='cuda:0') 0.23828125
# 22 0 tensor(0.3658, device='cuda:0') 0.0703125
# 22 1 tensor(0.1553, device='cuda:0') 0.203125
# 22 0 tensor(0.3722, device='cuda:0') 0.0703125
# 22 1 tensor(0.1734, device='cuda:0') 0.2421875
# 22 0 tensor(0.3574, device='cuda:0') 0.0546875
# 22 1 tensor(0.1831, device='cuda:0') 0.3046875
# 22 0 tensor(0.3654, device='cuda:0') 0.0234375
# 23 0 tensor(0.3219, device='cuda:0') 0.109375
# 23 1 tensor(0.2042, device='cuda:0') 0.2890625
# 23 0 tensor(0.3313, device='cuda:0') 0.1015625
# 23 1 tensor(0.2350, device='cuda:0') 0.34375
# 23 0 tensor(0.3012, device='cuda:0') 0.1015625
# 23 1 tensor(0.2624, device='cuda:0') 0.3984375
# 23 0 tensor(0.3045, device='cuda:0') 0.140625
# 23 1 tensor(0.2517, device='cuda:0') 0.375
# 23 0 tensor(0.2764, device='cuda:0') 0.1953125
# 23 1 tensor(0.2868, device='cuda:0') 0.42578125
# 23 0 tensor(0.2968, device='cuda:0') 0.140625
# 23 1 tensor(0.2932, device='cuda:0') 0.4453125
# 23 0 tensor(0.2655, device='cuda:0') 0.1796875
# 23 1 tensor(0.2755, device='cuda:0') 0.41015625
# 23 0 tensor(0.3209, device='cuda:0') 0.078125
# 23 1 tensor(0.2766, device='cuda:0') 0.41796875
# 23 0 tensor(0.3426, device='cuda:0') 0.078125
# 23 1 tensor(0.2514, device='cuda:0') 0.39453125
# 23 0 tensor(0.3650, device='cuda:0') 0.0390625
# 23 1 tensor(0.2007, device='cuda:0') 0.30078125
# 23 0 tensor(0.3976, device='cuda:0') 0.015625
# 23 1 tensor(0.1583, device='cuda:0') 0.22265625
# 23 0 tensor(0.4253, device='cuda:0') 0.0
# 23 1 tensor(0.1544, device='cuda:0') 0.22265625
# 23 0 tensor(0.4382, device='cuda:0') 0.0
# 23 1 tensor(0.1262, device='cuda:0') 0.1875
# 23 0 tensor(0.4490, device='cuda:0') 0.0
# 23 1 tensor(0.0994, device='cuda:0') 0.13671875
# 23 0 tensor(0.4621, device='cuda:0') 0.0
# 23 1 tensor(0.0797, device='cuda:0') 0.11328125
# 23 0 tensor(0.4677, device='cuda:0') 0.0
# 23 1 tensor(0.0716, device='cuda:0') 0.10546875
# 23 0 tensor(0.4687, device='cuda:0') 0.0
# 23 1 tensor(0.0477, device='cuda:0') 0.046875
# 23 0 tensor(0.4678, device='cuda:0') 0.0
# 23 1 tensor(0.0471, device='cuda:0') 0.06640625
# ...
# 92 0 tensor(0.3112, device='cuda:0') 0.078125
# 92 1 tensor(0.1060, device='cuda:0') 0.14453125
# 92 0 tensor(0.3111, device='cuda:0') 0.0625
# 92 1 tensor(0.1022, device='cuda:0') 0.12890625
# 92 0 tensor(0.3226, device='cuda:0') 0.0390625
# 92 1 tensor(0.1211, device='cuda:0') 0.171875
# 92 0 tensor(0.3276, device='cuda:0') 0.0390625
# 92 1 tensor(0.1066, device='cuda:0') 0.15234375
# 92 0 tensor(0.3176, device='cuda:0') 0.0703125
# 92 1 tensor(0.1056, device='cuda:0') 0.13671875
# 92 0 tensor(0.3253, device='cuda:0') 0.0234375
# 92 1 tensor(0.0954, device='cuda:0') 0.12109375
# 92 0 tensor(0.3233, device='cuda:0') 0.015625
# 92 1 tensor(0.0929, device='cuda:0') 0.13671875
# 92 0 tensor(0.3259, device='cuda:0') 0.0234375
# 92 1 tensor(0.1397, device='cuda:0') 0.2109375
# 92 0 tensor(0.3231, device='cuda:0') 0.0625
# 92 1 tensor(0.1170, device='cuda:0') 0.1640625
# 92 0 tensor(0.3263, device='cuda:0') 0.0078125
# 92 1 tensor(0.1227, device='cuda:0') 0.17578125
# 92 0 tensor(0.3315, device='cuda:0') 0.0234375
# 92 1 tensor(0.1035, device='cuda:0') 0.13671875
# 92 0 tensor(0.3247, device='cuda:0') 0.046875
# 92 1 tensor(0.1289, device='cuda:0') 0.1796875
# 92 0 tensor(0.3293, device='cuda:0') 0.015625
# 92 1 tensor(0.1238, device='cuda:0') 0.17578125
# 92 0 tensor(0.3331, device='cuda:0') 0.0234375
# 92 1 tensor(0.1224, device='cuda:0') 0.171875
# 92 0 tensor(0.3399, device='cuda:0') 0.015625
# 92 1 tensor(0.1341, device='cuda:0') 0.16796875
# 92 0 tensor(0.3170, device='cuda:0') 0.015625
# 92 1 tensor(0.1134, device='cuda:0') 0.1640625
# 92 0 tensor(0.3261, device='cuda:0') 0.0390625
# 92 1 tensor(0.1284, device='cuda:0') 0.19140625
# 92 0 tensor(0.3087, device='cuda:0') 0.0390625
# 93 0 tensor(0.3177, device='cuda:0') 0.0546875
# 93 1 tensor(0.1533, device='cuda:0') 0.21875
# 93 0 tensor(0.2883, device='cuda:0') 0.078125
# 93 1 tensor(0.1415, device='cuda:0') 0.1953125
# 93 0 tensor(0.2842, device='cuda:0') 0.078125
# 93 1 tensor(0.1397, device='cuda:0') 0.1875
# 93 0 tensor(0.2805, device='cuda:0') 0.140625
# 93 1 tensor(0.1391, device='cuda:0') 0.1953125
# 93 0 tensor(0.2655, device='cuda:0') 0.140625
# 93 1 tensor(0.1741, device='cuda:0') 0.26953125
# 93 0 tensor(0.2748, device='cuda:0') 0.109375
# 93 1 tensor(0.1572, device='cuda:0') 0.23828125
# 93 0 tensor(0.2754, device='cuda:0') 0.1171875
# 93 1 tensor(0.1544, device='cuda:0') 0.2421875
# 93 0 tensor(0.2798, device='cuda:0') 0.1328125
# 93 1 tensor(0.1337, device='cuda:0') 0.19921875
# 93 0 tensor(0.2977, device='cuda:0') 0.078125
# 93 1 tensor(0.1744, device='cuda:0') 0.2421875
# 93 0 tensor(0.2979, device='cuda:0') 0.0703125
# 93 1 tensor(0.1603, device='cuda:0') 0.23046875
# 93 0 tensor(0.2830, device='cuda:0') 0.1015625
# 93 1 tensor(0.1427, device='cuda:0') 0.23828125
# 93 0 tensor(0.3090, device='cuda:0') 0.0390625
# 93 1 tensor(0.1642, device='cuda:0') 0.25
# 93 0 tensor(0.2837, device='cuda:0') 0.1328125
# 93 1 tensor(0.1680, device='cuda:0') 0.25
# 93 0 tensor(0.2897, device='cuda:0') 0.1015625
# 93 1 tensor(0.1631, device='cuda:0') 0.2421875
# 93 0 tensor(0.2852, device='cuda:0') 0.125
# 93 1 tensor(0.1709, device='cuda:0') 0.26171875
# 93 0 tensor(0.2990, device='cuda:0') 0.125
# 93 1 tensor(0.1629, device='cuda:0') 0.234375
# 93 0 tensor(0.2765, device='cuda:0') 0.1015625
# 93 1 tensor(0.1697, device='cuda:0') 0.28125
# 93 0 tensor(0.3124, device='cuda:0') 0.0546875
# 93 1 tensor(0.1556, device='cuda:0') 0.23046875
# 93 0 tensor(0.2811, device='cuda:0') 0.1015625
# 93 1 tensor(0.1323, device='cuda:0') 0.1640625
# 93 0 tensor(0.2798, device='cuda:0') 0.1015625
# 93 1 tensor(0.1604, device='cuda:0') 0.24609375
# 93 0 tensor(0.2605, device='cuda:0') 0.1328125
# 93 1 tensor(0.1619, device='cuda:0') 0.25390625
# 93 0 tensor(0.2934, device='cuda:0') 0.1484375
# 93 1 tensor(0.1351, device='cuda:0') 0.1875
# 94 1 tensor(0.1426, device='cuda:0') 0.203125
# 94 0 tensor(0.3134, device='cuda:0') 0.046875
# 94 1 tensor(0.1383, device='cuda:0') 0.1875
# 94 0 tensor(0.3383, device='cuda:0') 0.0625
# 94 1 tensor(0.1080, device='cuda:0') 0.16015625
# 94 0 tensor(0.3249, device='cuda:0') 0.0859375
# 94 1 tensor(0.1277, device='cuda:0') 0.1640625
# 94 0 tensor(0.3235, device='cuda:0') 0.03125
# 94 1 tensor(0.1188, device='cuda:0') 0.16015625
# 94 0 tensor(0.3227, device='cuda:0') 0.0546875
# 94 1 tensor(0.1220, device='cuda:0') 0.16796875
# 94 0 tensor(0.3316, device='cuda:0') 0.03125
# 94 1 tensor(0.1207, device='cuda:0') 0.1640625
# 94 0 tensor(0.3457, device='cuda:0') 0.03125
# 94 1 tensor(0.1230, device='cuda:0') 0.16796875
# 94 0 tensor(0.3439, device='cuda:0') 0.0234375
# 94 1 tensor(0.1200, device='cuda:0') 0.16796875
# 94 0 tensor(0.3254, device='cuda:0') 0.03125
# 94 1 tensor(0.1189, device='cuda:0') 0.171875
# 94 0 tensor(0.3063, device='cuda:0') 0.1015625
# 94 1 tensor(0.1165, device='cuda:0') 0.15234375
# 94 0 tensor(0.3178, device='cuda:0') 0.0546875
# 94 1 tensor(0.1199, device='cuda:0') 0.16796875
# 94 0 tensor(0.3203, device='cuda:0') 0.0625
# 94 1 tensor(0.1035, device='cuda:0') 0.1328125
# 94 0 tensor(0.3131, device='cuda:0') 0.046875
# 94 1 tensor(0.1184, device='cuda:0') 0.1484375
# 94 0 tensor(0.3181, device='cuda:0') 0.03125
# 94 1 tensor(0.1102, device='cuda:0') 0.13671875
# 94 0 tensor(0.3258, device='cuda:0') 0.0390625
# 94 1 tensor(0.1126, device='cuda:0') 0.15234375
# 94 0 tensor(0.3436, device='cuda:0') 0.0078125
# 94 1 tensor(0.1342, device='cuda:0') 0.1875
# 94 0 tensor(0.3336, device='cuda:0') 0.0390625
# 94 1 tensor(0.1074, device='cuda:0') 0.13671875
# 94 0 tensor(0.3220, device='cuda:0') 0.0546875
# 94 1 tensor(0.1256, device='cuda:0') 0.18359375
# 94 0 tensor(0.3401, device='cuda:0') 0.0390625
# 94 1 tensor(0.1078, device='cuda:0') 0.1484375
# 94 0 tensor(0.3370, device='cuda:0') 0.03125
# 94 1 tensor(0.1085, device='cuda:0') 0.12890625
# 94 0 tensor(0.3340, device='cuda:0') 0.0234375
# 94 1 tensor(0.1136, device='cuda:0') 0.15625
# 94 0 tensor(0.3326, device='cuda:0') 0.03125
# 95 0 tensor(0.3360, device='cuda:0') 0.0234375
# 95 1 tensor(0.1118, device='cuda:0') 0.1484375
# 95 0 tensor(0.3251, device='cuda:0') 0.046875
# 95 1 tensor(0.1282, device='cuda:0') 0.1640625
# 95 0 tensor(0.3295, device='cuda:0') 0.046875
# 95 1 tensor(0.1372, device='cuda:0') 0.18359375
# 95 0 tensor(0.3205, device='cuda:0') 0.0546875
# 95 1 tensor(0.1370, device='cuda:0') 0.1953125
# 95 0 tensor(0.3310, device='cuda:0') 0.0234375
# 95 1 tensor(0.1336, device='cuda:0') 0.19921875
# 95 0 tensor(0.3266, device='cuda:0') 0.03125
# 95 1 tensor(0.1277, device='cuda:0') 0.16796875
# 95 0 tensor(0.3277, device='cuda:0') 0.0390625
# 95 1 tensor(0.1400, device='cuda:0') 0.1875
# 95 0 tensor(0.3026, device='cuda:0') 0.109375
# 95 1 tensor(0.1367, device='cuda:0') 0.18359375
# 95 0 tensor(0.3163, device='cuda:0') 0.0625
# 95 1 tensor(0.1244, device='cuda:0') 0.17578125
# 95 0 tensor(0.3168, device='cuda:0') 0.0703125
# 95 1 tensor(0.1264, device='cuda:0') 0.16796875
# 95 0 tensor(0.3251, device='cuda:0') 0.03125
# 95 1 tensor(0.1471, device='cuda:0') 0.20703125
# 95 0 tensor(0.3090, device='cuda:0') 0.0546875
# 95 1 tensor(0.1277, device='cuda:0') 0.1796875
# 95 0 tensor(0.2979, device='cuda:0') 0.046875
# 95 1 tensor(0.1455, device='cuda:0') 0.1953125
# 95 0 tensor(0.3145, device='cuda:0') 0.015625
# 95 1 tensor(0.1290, device='cuda:0') 0.1796875
# 95 0 tensor(0.3164, device='cuda:0') 0.046875
# 95 1 tensor(0.1230, device='cuda:0') 0.1875
# 95 0 tensor(0.3075, device='cuda:0') 0.0390625
# 95 1 tensor(0.1296, device='cuda:0') 0.17578125
# 95 0 tensor(0.3096, device='cuda:0') 0.0390625
# 95 1 tensor(0.1300, device='cuda:0') 0.17578125
# 95 0 tensor(0.2945, device='cuda:0') 0.0703125
# 95 1 tensor(0.1422, device='cuda:0') 0.2109375
# 95 0 tensor(0.3031, device='cuda:0') 0.0546875
# 95 1 tensor(0.1314, device='cuda:0') 0.18359375
# 95 0 tensor(0.2915, device='cuda:0') 0.0859375
# 95 1 tensor(0.1498, device='cuda:0') 0.21484375
# 95 0 tensor(0.2894, device='cuda:0') 0.0703125
# 95 1 tensor(0.1439, device='cuda:0') 0.1875
# 95 0 tensor(0.2812, device='cuda:0') 0.0859375
# 95 1 tensor(0.1287, device='cuda:0') 0.1484375
# 96 1 tensor(0.1363, device='cuda:0') 0.1875
# 96 0 tensor(0.3090, device='cuda:0') 0.109375
# 96 1 tensor(0.1498, device='cuda:0') 0.203125
# 96 0 tensor(0.3090, device='cuda:0') 0.046875
# 96 1 tensor(0.1495, device='cuda:0') 0.20703125
# 96 0 tensor(0.2963, device='cuda:0') 0.0859375
# 96 1 tensor(0.1466, device='cuda:0') 0.203125
# 96 0 tensor(0.2990, device='cuda:0') 0.0859375
# 96 1 tensor(0.1520, device='cuda:0') 0.22265625
# 96 0 tensor(0.2943, device='cuda:0') 0.078125
# 96 1 tensor(0.1436, device='cuda:0') 0.19140625
# 96 0 tensor(0.3136, device='cuda:0') 0.109375
# 96 1 tensor(0.1526, device='cuda:0') 0.21875
# 96 0 tensor(0.2901, device='cuda:0') 0.0859375
# 96 1 tensor(0.1348, device='cuda:0') 0.18359375
# 96 0 tensor(0.3018, device='cuda:0') 0.0859375
# 96 1 tensor(0.1239, device='cuda:0') 0.16015625
# 96 0 tensor(0.3132, device='cuda:0') 0.0625
# 96 1 tensor(0.1326, device='cuda:0') 0.19140625
# 96 0 tensor(0.3042, device='cuda:0') 0.046875
# 96 1 tensor(0.1406, device='cuda:0') 0.1953125
# 96 0 tensor(0.3087, device='cuda:0') 0.046875
# 96 1 tensor(0.1314, device='cuda:0') 0.18359375
# 96 0 tensor(0.2908, device='cuda:0') 0.078125
# 96 1 tensor(0.1485, device='cuda:0') 0.21875
# 96 0 tensor(0.2875, device='cuda:0') 0.109375
# 96 1 tensor(0.1327, device='cuda:0') 0.18359375
# 96 0 tensor(0.3052, device='cuda:0') 0.0625
# 96 1 tensor(0.1318, device='cuda:0') 0.19921875
# 96 0 tensor(0.2935, device='cuda:0') 0.0390625
# 96 1 tensor(0.1442, device='cuda:0') 0.21484375
# 96 0 tensor(0.3135, device='cuda:0') 0.078125
# 96 1 tensor(0.1317, device='cuda:0') 0.171875
# 96 0 tensor(0.3218, device='cuda:0') 0.046875
# 96 1 tensor(0.1343, device='cuda:0') 0.1875
# 96 0 tensor(0.3155, device='cuda:0') 0.0546875
# 96 1 tensor(0.1191, device='cuda:0') 0.16796875
# 96 0 tensor(0.3382, device='cuda:0') 0.0546875
# 96 1 tensor(0.1215, device='cuda:0') 0.1640625
# 96 0 tensor(0.3181, device='cuda:0') 0.0390625
# 96 1 tensor(0.1261, device='cuda:0') 0.16796875
# 96 0 tensor(0.3287, device='cuda:0') 0.03125
# 96 1 tensor(0.1046, device='cuda:0') 0.1484375
# 96 0 tensor(0.3367, device='cuda:0') 0.0234375
# 97 0 tensor(0.3127, device='cuda:0') 0.0546875
# 97 1 tensor(0.1355, device='cuda:0') 0.1796875
# 97 0 tensor(0.3271, device='cuda:0') 0.03125
# 97 1 tensor(0.1119, device='cuda:0') 0.16015625
# 97 0 tensor(0.3313, device='cuda:0') 0.0
# 97 1 tensor(0.0952, device='cuda:0') 0.13671875
# 97 0 tensor(0.3315, device='cuda:0') 0.0390625
# 97 1 tensor(0.1015, device='cuda:0') 0.1484375
# 97 0 tensor(0.3401, device='cuda:0') 0.03125
# 97 1 tensor(0.0985, device='cuda:0') 0.1484375
# 97 0 tensor(0.3321, device='cuda:0') 0.046875
# 97 1 tensor(0.1157, device='cuda:0') 0.1640625
# 97 0 tensor(0.3423, device='cuda:0') 0.0234375
# 97 1 tensor(0.1112, device='cuda:0') 0.15234375
# 97 0 tensor(0.3362, device='cuda:0') 0.0234375
# 97 1 tensor(0.1085, device='cuda:0') 0.14453125
# 97 0 tensor(0.3312, device='cuda:0') 0.03125
# 97 1 tensor(0.1173, device='cuda:0') 0.171875
# 97 0 tensor(0.3222, device='cuda:0') 0.0703125
# 97 1 tensor(0.1091, device='cuda:0') 0.13671875
# 97 0 tensor(0.3223, device='cuda:0') 0.078125
# 97 1 tensor(0.0919, device='cuda:0') 0.1171875
# 97 0 tensor(0.3165, device='cuda:0') 0.046875
# 97 1 tensor(0.1000, device='cuda:0') 0.12890625
# 97 0 tensor(0.3188, device='cuda:0') 0.0625
# 97 1 tensor(0.1286, device='cuda:0') 0.19921875
# 97 0 tensor(0.3035, device='cuda:0') 0.0859375
# 97 1 tensor(0.1146, device='cuda:0') 0.15625
# 97 0 tensor(0.3114, device='cuda:0') 0.0703125
# 97 1 tensor(0.0974, device='cuda:0') 0.12890625
# 97 0 tensor(0.3020, device='cuda:0') 0.0859375
# 97 1 tensor(0.1269, device='cuda:0') 0.19140625
# 97 0 tensor(0.3016, device='cuda:0') 0.0859375
# 97 1 tensor(0.1160, device='cuda:0') 0.1328125
# 97 0 tensor(0.3018, device='cuda:0') 0.0546875
# 97 1 tensor(0.1170, device='cuda:0') 0.14453125
# 97 0 tensor(0.2911, device='cuda:0') 0.109375
# 97 1 tensor(0.1152, device='cuda:0') 0.15625
# 97 0 tensor(0.3008, device='cuda:0') 0.125
# 97 1 tensor(0.1409, device='cuda:0') 0.20703125
# 97 0 tensor(0.3011, device='cuda:0') 0.0859375
# 97 1 tensor(0.1300, device='cuda:0') 0.19140625
# 97 0 tensor(0.3069, device='cuda:0') 0.0859375
# 97 1 tensor(0.1250, device='cuda:0') 0.1796875
# 98 1 tensor(0.1483, device='cuda:0') 0.22265625
# 98 0 tensor(0.3094, device='cuda:0') 0.078125
# 98 1 tensor(0.1519, device='cuda:0') 0.21484375
# 98 0 tensor(0.3038, device='cuda:0') 0.0625
# 98 1 tensor(0.1670, device='cuda:0') 0.24609375
# 98 0 tensor(0.3276, device='cuda:0') 0.0546875
# 98 1 tensor(0.1601, device='cuda:0') 0.2421875
# 98 0 tensor(0.3017, device='cuda:0') 0.125
# 98 1 tensor(0.1602, device='cuda:0') 0.2421875
# 98 0 tensor(0.2967, device='cuda:0') 0.0625
# 98 1 tensor(0.1651, device='cuda:0') 0.24609375
# 98 0 tensor(0.3005, device='cuda:0') 0.0546875
# 98 1 tensor(0.1657, device='cuda:0') 0.24609375
# 98 0 tensor(0.2717, device='cuda:0') 0.1328125
# 98 1 tensor(0.1625, device='cuda:0') 0.2421875
# 98 0 tensor(0.2809, device='cuda:0') 0.125
# 98 1 tensor(0.1630, device='cuda:0') 0.2421875
# 98 0 tensor(0.2674, device='cuda:0') 0.1796875
# 98 1 tensor(0.1710, device='cuda:0') 0.23046875
# 98 0 tensor(0.2583, device='cuda:0') 0.171875
# 98 1 tensor(0.1855, device='cuda:0') 0.2890625
# 98 0 tensor(0.2646, device='cuda:0') 0.1328125
# 98 1 tensor(0.1610, device='cuda:0') 0.23046875
# 98 0 tensor(0.2823, device='cuda:0') 0.0859375
# 98 1 tensor(0.1719, device='cuda:0') 0.2421875
# 98 0 tensor(0.2796, device='cuda:0') 0.0859375
# 98 1 tensor(0.1760, device='cuda:0') 0.26171875
# 98 0 tensor(0.2942, device='cuda:0') 0.0625
# 98 1 tensor(0.1680, device='cuda:0') 0.2421875
# 98 0 tensor(0.2988, device='cuda:0') 0.03125
# 98 1 tensor(0.1463, device='cuda:0') 0.19921875
# 98 0 tensor(0.3010, device='cuda:0') 0.046875
# 98 1 tensor(0.1516, device='cuda:0') 0.20703125
# 98 0 tensor(0.3182, device='cuda:0') 0.0625
# 98 1 tensor(0.1296, device='cuda:0') 0.1953125
# 98 0 tensor(0.3224, device='cuda:0') 0.0703125
# 98 1 tensor(0.1573, device='cuda:0') 0.2265625
# 98 0 tensor(0.3102, device='cuda:0') 0.078125
# 98 1 tensor(0.1227, device='cuda:0') 0.1640625
# 98 0 tensor(0.3197, device='cuda:0') 0.0625
# 98 1 tensor(0.1272, device='cuda:0') 0.19140625
# 98 0 tensor(0.3397, device='cuda:0') 0.015625
# 98 1 tensor(0.1351, device='cuda:0') 0.1953125
# 98 0 tensor(0.3166, device='cuda:0') 0.078125
# 99 0 tensor(0.3258, device='cuda:0') 0.0625
# 99 1 tensor(0.1262, device='cuda:0') 0.171875
# 99 0 tensor(0.3479, device='cuda:0') 0.0234375
# 99 1 tensor(0.1030, device='cuda:0') 0.13671875
# 99 0 tensor(0.3330, device='cuda:0') 0.078125
# 99 1 tensor(0.1327, device='cuda:0') 0.18359375
# 99 0 tensor(0.3211, device='cuda:0') 0.078125
# 99 1 tensor(0.1350, device='cuda:0') 0.20703125
# 99 0 tensor(0.3461, device='cuda:0') 0.0703125
# 99 1 tensor(0.1357, device='cuda:0') 0.2109375
# 99 0 tensor(0.3056, device='cuda:0') 0.140625
# 99 1 tensor(0.1371, device='cuda:0') 0.1953125
# 99 0 tensor(0.3388, device='cuda:0') 0.0625
# 99 1 tensor(0.1435, device='cuda:0') 0.1953125
# 99 0 tensor(0.3506, device='cuda:0') 0.0703125
# 99 1 tensor(0.1254, device='cuda:0') 0.19140625
# 99 0 tensor(0.3372, device='cuda:0') 0.0546875
# 99 1 tensor(0.1428, device='cuda:0') 0.21484375
# 99 0 tensor(0.3451, device='cuda:0') 0.0703125
# 99 1 tensor(0.1362, device='cuda:0') 0.2109375
# 99 0 tensor(0.3380, device='cuda:0') 0.0859375
# 99 1 tensor(0.1302, device='cuda:0') 0.16796875
# 99 0 tensor(0.3389, device='cuda:0') 0.0625
# 99 1 tensor(0.1258, device='cuda:0') 0.18359375
# 99 0 tensor(0.3414, device='cuda:0') 0.0546875
# 99 1 tensor(0.1456, device='cuda:0') 0.1875
# 99 0 tensor(0.3348, device='cuda:0') 0.0625
# 99 1 tensor(0.1273, device='cuda:0') 0.19140625
# 99 0 tensor(0.3355, device='cuda:0') 0.0390625
# 99 1 tensor(0.1492, device='cuda:0') 0.20703125
# 99 0 tensor(0.3461, device='cuda:0') 0.0546875
# 99 1 tensor(0.1447, device='cuda:0') 0.234375
# 99 0 tensor(0.3307, device='cuda:0') 0.078125
# 99 1 tensor(0.1664, device='cuda:0') 0.22265625
# 99 0 tensor(0.3482, device='cuda:0') 0.046875
# 99 1 tensor(0.1370, device='cuda:0') 0.19140625
# 99 0 tensor(0.3376, device='cuda:0') 0.078125
# 99 1 tensor(0.1520, device='cuda:0') 0.21875
# 99 0 tensor(0.3289, device='cuda:0') 0.046875
# 99 1 tensor(0.1380, device='cuda:0') 0.1640625
# 99 0 tensor(0.3384, device='cuda:0') 0.046875
# 99 1 tensor(0.1389, device='cuda:0') 0.20703125
# 99 0 tensor(0.3308, device='cuda:0') 0.0703125
# 99 1 tensor(0.1224, device='cuda:0') 0.1640625

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs

# %%
# train_kwargs['max_epochs'] = 100

# %%
# dm = SneakersGANDataModule('data', batch_size=BATCH_SIZE)
# model = DCGAN(*IMAGE_SIZE, 3, NOISE_DIM)
# trainer = pl.Trainer(**train_kwargs)
# trainer.fit(model, dm)

# %% [markdown]
# Prepare data for **III. GAN metrics. PRD score**:

# %%
import tqdm

def predict(
        model: torch.nn.Module,
        data: torch.Tensor,
        batch_size: int,
        verbose: bool = True
) -> torch.Tensor:
    output = []
    slicer = range(0, len(data), batch_size)
    if verbose:
        slicer = tqdm.tqdm(slicer)

    model.eval()
    use_gpu = torch.cuda.is_available()
    if use_gpu:
        model.cuda()
    with torch.no_grad():
        for i in slicer:
            x = data[i:i + batch_size]
            if use_gpu:
                x = x.cuda()
            y = model(x)
            if use_gpu:
                y = y.cpu()
            output.append(y)
    if use_gpu:
        model.cpu()
        
    output = torch.cat(output, dim=0)
    return output

# %%
dataset = SneakersDataset('data', target_size=IMAGE_SIZE)
lr_data = torch.stack([dataset[i] for i in range(len(dataset))], dim=0)
dc_fake_data = predict(dl_gen, torch.randn(lr_data.size(0), NOISE_DIM), BATCH_SIZE)
print('LR data:', lr_data.size())
print('Fake LR data:', dc_fake_data.size())
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 67.15it/s]
# LR data: torch.Size([5729, 28, 28, 3])
# Fake LR data: torch.Size([5729, 28, 28, 3])

# %%
score,  _, _ = calculate_prd_score(lr_data, dc_fake_data)
print("Score:", score)
# Out:
# Score: 2.132742746596679e-06

# %%
visualize_images(dl_gen(torch.randn(32, NOISE_DIM)).cpu().detach(), 4, 8)

# %%
visualize_images(dl_gen(torch.randn(32, NOISE_DIM).to(device)).cpu().detach(), 4, 8)

# %%
visualize_images(dl_gen(torch.randn(32, NOISE_DIM).to(device)).cpu().detach(), 4, 8)

# %% [markdown]
# # II. Super Resolution
#
# In this part of the notebook you will train a generative model that solves an image-to-image problem, with "small images" as a source domain and "large images" being a target domain.
#
# To specify the task, you are to **scale small images of 28x28 pixels up to size of 112x112 pixels**.

# %%
# class SneakersSRDataModule(pl.LightningDataModule):
#     def __init__(self, data_dir: str, batch_size, shuffle=True):
#         super().__init__()
#         self.data_dir = data_dir
#         self.batch_size = batch_size
#         self.shuffle = shuffle
    
#     def setup(self, stage=None):
#         self.dataset = SneakersDataset(self.data_dir, input_size=LOW_RES_SIZE, target_size=HIGH_RES_SIZE)
    
#     def train_dataloader(self):
#         return torch.utils.data.DataLoader(self.dataset, batch_size=self.batch_size, shuffle=self.shuffle)

# %%
dataset = SneakersDataset(
    "data",
    input_size=LOW_RES_SIZE,
    target_size=HIGH_RES_SIZE
)

dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=SMALL_BATCH_SIZE,
    shuffle=True
)

# %%
real_data_lr, real_data_hr = next(iter(dataloader))

assert real_data_lr.shape[1:] == LOW_RES_SIZE + (3,)
assert real_data_hr.shape[1:] == HIGH_RES_SIZE + (3,)

plt.figure(figsize=(8, 14))
for i in range(SMALL_BATCH_SIZE):
    plt.subplot(SMALL_BATCH_SIZE, 2, 2 * i + 1)
    plt.title("Low resolution")
    plt.imshow(data2img(real_data_lr[i]))
    plt.axis("off")

    plt.subplot(SMALL_BATCH_SIZE, 2, 2 * i + 2)
    plt.title("High resolution")
    plt.imshow(data2img(real_data_hr[i]))
    plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-27678319a513> in <module>
# ----> 1 real_data_lr, real_data_hr = next(iter(dataloader))
#       2
#       3 assert real_data_lr.shape[1:] == LOW_RES_SIZE + (3,)
#       4 assert real_data_hr.shape[1:] == HIGH_RES_SIZE + (3,)
#       5
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# In the second part of this task, you are to train an [SRGAN](https://arxiv.org/abs/1609.04802)-like model. For your convinience, some layers are already implemented. Now it's your turn -- fill the gaps so the model passes the asserts below.

# %% [markdown]
# ### Generator (1.5 pts) [cross-check:6]

# %% [markdown]
# To build a SRGAN Generator, you will need a basic Residual Block(filters):
#
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * ReLU
# * Batch Normalization 2D with momentum(0.8)
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * Batch Normalization 2D with momentum(0.8)
# * Sum up outputs with inputs

# %%
class ResidualBlock(torch.nn.Module):
    def __init__(self, filters: int):
        super().__init__()
        self._model = torch.nn.Sequential(
            torch.nn.Conv2d(
                in_channels=filters,
                out_channels=filters,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.ReLU(inplace=True),
            torch.nn.BatchNorm2d(
                num_features=filters,
                momentum=0.8
            ),
            torch.nn.Conv2d(
                in_channels=filters,
                out_channels=filters,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.BatchNorm2d(
                num_features=filters,
                momentum=0.8
            )
        )
        
    def forward(self, z):
        zc = self._model(z)
        return zc + z

# %% [markdown]
# Upsampling Block(filters):
#
# * UpSampling2D(2)
# * Conv2D: 3x3, filters=filters, strides=1, padding="same"
# * ReLU

# %%
class UpsamplingBlock(torch.nn.Module):
    def __init__(
            self,
            filters: int,
            input_filters: tp.Optional[int] = None
    ):
        super().__init__()
        input_filters = filters if input_filters is None else input_filters
        self._model = torch.nn.Sequential(
            torch.nn.Upsample(scale_factor=2, mode='bilinear'),
            torch.nn.Conv2d(
                in_channels=input_filters,
                out_channels=filters,
                kernel_size=(3, 3),
                stride=(1, 1),
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.ReLU(inplace=True)
        )
        
    def forward(self, z):
        return self._model(z)

# %% [markdown]
# Now, using these basic building blocks, one is able to define a SRGAN generator:

# %%
class SRGenerator(torch.nn.Module):
    def __init__(self):
        super().__init__()

        self._init_conv = torch.nn.Sequential(
            torch.nn.Conv2d(3, 64, kernel_size=9, padding=9 // 2, padding_mode='zeros'),
            torch.nn.ReLU(inplace=True)
        )
        self._residual_chain = torch.nn.Sequential(
            *[ResidualBlock(64) for _ in range(16)],
            torch.nn.Conv2d(64, 64, kernel_size=3, padding=3 // 2, padding_mode='zeros'),
            torch.nn.BatchNorm2d(64, momentum=0.8)
        )
        self._upsample_conv = torch.nn.Sequential(
            UpsamplingBlock(256, input_filters=64),
            UpsamplingBlock(256),
            torch.nn.Conv2d(256, 3, kernel_size=9, padding=9 // 2, padding_mode='zeros'),
            torch.nn.Tanh()
        )
    
    def forward(self, z):
        x = z.permute(0, 3, 1, 2)
        conv = self._init_conv(x)
        x = self._residual_chain(conv) + conv
        img = self._upsample_conv(x)
        img = img.permute(0, 2, 3, 1)  # make channel axis last
        return img

# %%
# real_data_lr, real_data_hr = next(iter(dm.train_dataloader()))
real_data_lr, real_data_hr = next(iter(dataloader))
fake_hr = SRGenerator()(real_data_lr)
assert fake_hr.shape == real_data_hr.shape

# %% [markdown]
# ### Discriminator (1.5 pts) [cross-check:7]

# %% [markdown]
# First, define a Discriminator Block(filters, strides):
#
# * Conv2D: 3x3, filters=filters, strides=strides, padding="same"
# * Leaky ReLU(0.2)
# * (optional) Batch Normalization 2D with momentum(0.8)

# %%
class DBlock(torch.nn.Module):
    def __init__(
            self, 
            input_filters: int,
            filters: int,
            strides: tp.Tuple[int, int],
            batch_norm: bool = False
    ):
        super().__init__()
        layers = [
            torch.nn.Conv2d(
                in_channels=input_filters,
                out_channels=filters,
                kernel_size=(3, 3),
                stride=strides,
                padding=(1, 1),
                padding_mode="zeros"
            ),
            torch.nn.LeakyReLU(negative_slope=0.2)
        ]
        if batch_norm:
            layers.append(torch.nn.BatchNorm2d(filters, momentum=0.8))
        self._model = torch.nn.Sequential(*layers)
    
    def forward(self, z):
        return self._model(z)

# %% [markdown]
# Now, use this block to build up SRGAN discriminator:
#
# * DBlock(filters=64, strides=1) with Batch Normalization
# * DBlock(filters=64, strides=2)
# * DBlock(filters=128, strides=1)
# * DBlock(filters=128, strides=2)
# * DBlock(filters=256, strides=1)
# * DBlock(filters=256, strides=2)
# * DBlock(filters=512, strides=1)
# * DBlock(filters=512, strides=2)
# * Flatten
# * Fully connected with output size of 1024
# * Leaky ReLU(0.2)
# * Fully connected with output size of 1
# * Sigmoid

# %%
class Flatten(torch.nn.Module):
    def forward(self, x: torch.Tensor):
        return x.flatten(1)

class SRDiscriminator(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self._model = nn.Sequential(
            DBlock(3, 64, strides=(1, 1), batch_norm=True),  # out: 64x112x112
            DBlock(64, 64, strides=(2, 2)),  # out: 64x56x56 
            DBlock(64, 128, strides=(1, 1)),  # out: 128x56x56
            DBlock(128, 128, strides=(2, 2)),  # out: 128x28x28
            DBlock(128, 256, strides=(1, 1)),  # out: 256x28x28
            DBlock(256, 256, strides=(2, 2)),  # out: 256x14x14
            DBlock(256, 512, strides=(1, 1)),  # out: 512x14x14
            DBlock(512, 512, strides=(2, 2)),  # out: 512x7x7
            Flatten(),  # out: 25088
            torch.nn.Linear(25088, 1024),
            torch.nn.LeakyReLU(negative_slope=0.2),
            torch.nn.Linear(1024, 1),
            torch.nn.Sigmoid()
        )
    
    def forward(self, z):
        x = z.permute(0, 3, 1, 2)
        return self._model(x)

# %%
fake_probas = SRDiscriminator()(fake_hr)
assert fake_probas.shape[1:] == (1,)

# %% [markdown]
# Typically, SRGAN is trained with additional loss on features from pretrained VGG-19. However, you task will be a bit simplier: use **mean squared error** between real and fake data instead.

# %%
# class SRGAN(pl.LightningModule):
#     def __init__(self, validation_lr):
#         super().__init__()
        
#         self.generator = SRGenerator()
#         self.discriminator = SRDiscriminator()

#         self.validation_lr = validation_lr
        
#     def forward(self, z):
#         return self.generator(z)
    
#     def gan_loss(self, y_hat, y):
#         return  # TODO: implement loss
    
#     def ls_loss(self, y_hat, y):
#         return  # TODO: implement loss
    
#     def mse_loss(self, sr_imgs, hr_imgs):
#         return  # TODO: implement MSE loss
    
#     def training_step(self, imgs, batch_idx, optimizer_idx):
#         lr_imgs, hr_imgs = imgs
        
#         if optimizer_idx == 0:  # generator
#             sr_imgs = self(lr_imgs)
            
#             valid = torch.ones(lr_imgs.size(0), 1)  # all fake, but we want to be real
#             valid = valid.type_as(lr_imgs)
            
#             gan_loss = self.gan_loss(self.discriminator(sr_imgs), valid)
#             mse_loss = self.mse_loss(sr_imgs, hr_imgs)
            
#             g_loss = 1 * mse_loss + 0.5 * gan_loss
#             self.log('g_loss', g_loss, prog_bar=True)
#             self.log('gan_loss', gan_loss, prog_bar=True)
#             self.log('mse_loss', mse_loss, prog_bar=True)
#             return g_loss
        
#         if optimizer_idx == 1:  # discriminator
#             valid = torch.ones(hr_imgs.size(0), 1)
#             valid = valid.type_as(hr_imgs)
#             real_loss = self.ls_loss(self.discriminator(hr_imgs), valid)
            
#             fake = torch.zeros(lr_imgs.size(0), 1)
#             fake = fake.type_as(lr_imgs)
#             fake_loss = self.ls_loss(self.discriminator(self(lr_imgs).detach()), fake)
            
#             d_loss = (real_loss + fake_loss) / 2
#             self.log('d_loss', d_loss, prog_bar=True)
#             return d_loss
    
#     def configure_optimizers(self):
#         opt_g = torch.optim.Adam(self.generator.parameters(), lr=2e-4, betas=(0.5, 0.999))
#         opt_d = torch.optim.Adam(self.discriminator.parameters(), lr=1e-3, betas=(0.5, 0.999))
#         return [opt_g, opt_d], []

#     def on_epoch_end(self):
#         z = self.validation_lr.type_as(self.generator.init_conv[0].weight)
#         sample_imgs = self(z).permute(0, 3, 1, 2)  # channels before pixels
#         grid = torchvision.utils.make_grid(sample_imgs)
#         self.logger.experiment.add_image('generated_images', grid, self.current_epoch)

# %% [markdown]
# ### Training

# %%
batch_size = BATCH_SIZE

dataset = SneakersDataset(
    "data",
    input_size=LOW_RES_SIZE,
    target_size=HIGH_RES_SIZE
)

dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)

batch_size
# Out:
# 128

# %%
loss_dis = lambda y_pred, y: (
    -(
        torch.log(y_pred[y == 1]) +
        torch.log((1 - y_pred[y == 0]))
    ) * 0.5
).mean()

loss_gen = lambda y_pred, y: -(-torch.log(y_pred[y == 1]).mean())
# loss_gen = lambda y_pred, y: -torch.log(1 - y_pred[y == 1]).mean()

# %%
srgan_dis = SRDiscriminator()
srgan_gen = SRGenerator()

# loss_dis = lambda y_pred, y: (y_pred[y == 1] ** 2 + (1 - y_pred[y == 0])**2).mean() * 0.5
# loss_gen = lambda y_pred, y: ((1 - y_pred[y == 1]) ** 2).mean() * 0.5
loss_mse = torch.nn.MSELoss()

optimizer_dis = torch.optim.Adam(srgan_dis.parameters(), lr=0.0001)
optimizer_gen = torch.optim.Adam(srgan_gen.parameters(), lr=0.0001)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
srgan_dis = srgan_dis.to(device)
srgan_gen = srgan_gen.to(device)
device
# Out:
# device(type='cuda', index=0)

# %%
epoch_nums = 80

for epoch in range(epoch_nums):
    optimizer_indx = epoch % 2
    for X, Y_real in dataloader:
        X = X.to(device)
        optimizer_dis.zero_grad()
        optimizer_gen.zero_grad()
        if optimizer_indx == 0:
            srgan_gen = srgan_gen.eval()
            srgan_dis = srgan_dis.train()
            Y_fake = srgan_gen(X).detach().cpu()
            X = torch.concat((Y_real, Y_fake))
            y = torch.concat((torch.zeros(batch_size, 1), torch.ones(batch_size, 1)))
            X = X.to(device)
            y = y.to(device)
            y_pred = srgan_dis(X)
            loss_value = loss_dis(y_pred, y)
            loss_value.backward()
            optimizer_dis.step()
        else:
            srgan_dis = srgan_dis.eval()
            srgan_gen = srgan_gen.train()
            Y_fake = srgan_gen(X)
            y = torch.ones(batch_size, 1).to(device)
            y_pred = srgan_dis(Y_fake)
            Y_real = Y_real.to(device)
            loss_value = loss_gen(y_pred, y) * 0.001 + loss_mse(Y_fake, Y_real)          
            loss_value.backward()
            optimizer_gen.step()
        print(epoch, 1 - optimizer_indx, loss_value.data, (y == (y_pred > 0.5).long()).cpu().numpy().mean())

        optimizer_indx = 1 - optimizer_indx

# %%
N = 4
real_data_lr, real_data_hr = next(iter(dataloader))
fake_data_hr = srgan_gen.eval()(real_data_lr.to(device)).detach().cpu()

real_data_lr = real_data_lr[:N]
real_data_hr = real_data_hr[:N]
fake_data_hr = fake_data_hr[:N]

plt.figure(figsize=(12, 14))
for i in range(SMALL_BATCH_SIZE):
    plt.subplot(SMALL_BATCH_SIZE, 3, 3 * i + 1)
    plt.title("Low resolution")
    plt.imshow(data2img(real_data_lr[i]))
    plt.axis("off")

    plt.subplot(SMALL_BATCH_SIZE, 3, 3 * i + 2)
    plt.title("High resolution")
    plt.imshow(data2img(real_data_hr[i]))
    plt.axis("off")

    plt.subplot(SMALL_BATCH_SIZE, 3, 3 * i + 3)
    plt.title("High resolution (FAKE)")
    plt.imshow(data2img(fake_data_hr[i]))
    plt.axis("off")

plt.show()

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs

# %%
# train_kwargs['max_epochs'] = 9

# %%
# dm = SneakersSRDataModule('data', batch_size=16)
# dm.setup()
# model = SRGAN(validation_lr=next(iter(dm.train_dataloader()))[0][:4])
# trainer = pl.Trainer(**train_kwargs)
# trainer.fit(model, dm)

# %% [markdown]
# Prepare data for **III. GAN metrics**:

# %%
# dm = SneakersSRDataModule('data', batch_size=BATCH_SIZE)
# dm.setup()
# hr_data = []
# for lr, hr in dm.train_dataloader():
#     hr_data.append(hr)
# hr_data = torch.cat(hr_data, dim=0)

# batch_size = 16
# sr_fake_data_from_real_lr = predict(model, lr_data, batch_size)
# sr_fake_data_from_fake_lr = predict(model, dc_fake_data, batch_size)
# print('HR data:', hr_data.size())
# print('SR from real LR:', sr_fake_data_from_real_lr.size())
# print('SR from fake LR:', sr_fake_data_from_fake_lr.size())

# %%
# visualize_images(sr_fake_data_from_real_lr, 4, 8)

# %%
# visualize_images(sr_fake_data_from_fake_lr, 4, 8)

# %% [markdown]
# # III. GAN metrics

# %% [markdown]
# There exists a few metrics used to measure GAN performance. Some of them are based on comparing real samples against generated ones, while the other rely on additional pretrained models that are applied to both real and generated data in order to accumulate high-level statistics. In this task, you are going to use two metrics representing these two approaches -- namely, [Precision-Recall Density](https://arxiv.org/pdf/1806.00035) and [Fréchet Inception Distance](https://arxiv.org/pdf/1706.08500).

# %% [markdown]
# ##  Precision-Recall Density (PRD score) (1.0 pts) [cross-check:8]
#
# Your first task is to implement [Precision-Recall Density](https://arxiv.org/pdf/1806.00035.pdf) score.

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

def bin_counts(
        real_data: np.array,
        fake_data: np.array,
        n_bins: int = 25
) -> tp.Tuple[np.array, np.array]:
    real_data = real_data.reshape(len(real_data), -1)
    fake_data = fake_data.reshape(len(fake_data), -1)

    data = np.vstack([real_data, fake_data])

    kmeans = MiniBatchKMeans(n_clusters=n_bins, n_init=10).fit(data)
    
    real_labels = kmeans.labels_[:len(real_data)]
    fake_labels = kmeans.labels_[len(real_data):]

    real_density = np.histogram(
        real_labels,
        bins=n_bins,
        range=[0, n_bins],
        density=True
    )[0]

    fake_density = np.histogram(
        fake_labels,
        bins=n_bins,
        range=[0, n_bins],
        density=True
    )[0]
    
    return real_density, fake_density


def sample_bin_counts(
        real_data: np.array,
        fake_data: np.array,
        n_bins: int = 25,
        repeat_number: int = 10,
        verbose: bool = True
) -> tp.Tuple[np.array, np.array]:
    real_densities = []
    fake_densities = []
    counter = range(repeat_number)
    if verbose:
        counter = tqdm.tqdm(counter)
    for _ in counter:
        real, fake = bin_counts(real_data, fake_data, n_bins=n_bins)
        real_densities.append(real)
        fake_densities.append(fake)
    return (
        np.array(real_densities).mean(axis=0),
        np.array(fake_densities).mean(axis=0)
    )

# %%
import math
from sklearn.metrics import auc

def calculate_alpha_beta(
        real_density: np.array, 
        fake_density: np.array,
        n_thetas: int = 1000
) -> tp.Tuple[list, list]:
    assert real_density.shape == fake_density.shape
    alpha, beta = [], []
    thetas = np.linspace(1e-6, np.pi / 2 - 1e-6, num=n_thetas)
    for theta in thetas:
        lambda_ = math.tan(theta)
        alpha.append(
            np.min((fake_density * lambda_, real_density)).sum()
        )
        beta.append(
            np.min((fake_density, real_density / lambda_)).sum()
        )
    return alpha, beta


def calculate_prd_score(
        real_data: torch.Tensor,
        fake_data: torch.Tensor
) -> tp.Any:
    # Calculate bin counts from real and generated data multiple times
    real_data = real_data.numpy()
    fake_data = fake_data.numpy()
    real_density, fake_density = bin_counts(real_data, fake_data)

    plt.bar(range(len(real_density)), real_density, width=1, color='g', alpha=0.5, label="Real density")
    plt.bar(range(len(fake_density)), fake_density, width=1, color='r', alpha=0.5, label="Fake density")
    plt.legend()
    plt.show()

    # Calculate alpha and beta
    alpha, beta = calculate_alpha_beta(real_density, fake_density)
    
    # Calculate area under curve (AUC) for alpha and beta
    score = auc(alpha, beta)

    return score, alpha, beta

# %% [markdown]
# Calculate PRD score for DCGAN (task I). You should pass `lr_data` and `dc_fake_data` to scoring function.

# %%
score,  _, _ = calculate_prd_score(lr_data, dc_fake_data)
print("Score:", score)
# Out:
# Score: 0.0

# %% [markdown]
# Now use PRD score to compare high resolution data generated from real low resolution data (`sr_fake_data_from_real_lr`) and fake resolution data (`sr_fake_data_from_fake_lr`):

# %%
# print("Generated from real LR")
# score_real, alpha_real, beta_real = calculate_prd_score(hr_data, sr_fake_data_from_real_lr)
# print("Score:", score_real, end='\n\n')

# print("Generated from fake LR")
# score_fake, alpha_fake, beta_fake = calculate_prd_score(hr_data, sr_fake_data_from_fake_lr)
# print("Score:", score_fake, end='\n\n')

# fig, ax = plt.subplots(figsize=(8, 8))
# ax.tick_params(axis="both", which="major", labelsize=8)
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.xlabel("Recall")
# plt.ylabel("Precision")
# plt.plot(alpha_real, beta_real, color='g', label="Generated from real LR")
# plt.plot(alpha_fake, beta_fake, color='r', label="Generated from fake LR")
# plt.legend()
# plt.show()

# %% [markdown]
# ## Fréchet Inception Distance (FID score) (1.0 pts) [cross-check:9]
#
# [Frechet Inception Distance](https://arxiv.org/pdf/1706.08500) is an improved version of [Inception score](https://arxiv.org/abs/1606.03498), that additionally calculates the statistics of real data and compares it to the statistics of generated data. It is probably the most widely-used option for evaluating GANs, and relies on features extracted with [InceptionV3](https://arxiv.org/abs/1512.00567) pretrained on ImageNet. These features assumed to come from a multivariate Gaussian distribution, so Fréchet distance between two multivariate Gaussians can be calculated:
#
# $$\text{FID} = ||\mu_r - \mu_g||^2 + \text{Tr} (\Sigma_r + \Sigma_g - 2 (\Sigma_r \Sigma_g)^{1/2}),$$
#
# where $X_r \sim \mathcal{N} (\mu_r, \Sigma_r)$ and $X_g \sim \mathcal{N} (\mu_g, \Sigma_g)$ are the 2048-dimensional activations of the Inception-v3 pool3 layer for real and generated samples respectively.

# %% [markdown]
# First, create InceptionV3 ([from torch repository](https://pytorch.org/hub/pytorch_vision_inception_v3/)) model. As you will be using it for feature extraction only, we should remove last fully connected layer.

# %%
class InceptionHeadless(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self._upsample = nn.Upsample(scale_factor=2)
        self._model = torch.hub.load(
            'pytorch/vision',
            'inception_v3',
            pretrained=True
        )
        self._model.fc = torch.nn.Identity()  # remove last fc layer
    
    def forward(self, z):
        x = z.permute(0, 3, 1, 2)
        x = self._upsample(x)
        return self._model(x)

# %%
inception = InceptionHeadless()
inception.eval()

with torch.no_grad():
    assert inception(lr_data[:32]).shape[1:] == (2048,)
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/main" to /root/.cache/torch/hub/main.zip
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-139-a4f7c7e5a330> in <module>
#       3
#       4 with torch.no_grad():
# ----> 5     assert inception(lr_data[:32]).shape[1:] == (2048,)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-138-7101466a6e87> in forward(self, z)
#      13         x = z.permute(0, 3, 1, 2)
#      14         x = self._upsample(x)
# ---> 15         return self._model(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/inception.py in forward(self, x)
#     164     def forward(self, x: Tensor) -> InceptionOutputs:
#     165         x = self._transform_input(x)
# --> 166         x, aux = self._forward(x)
#     167         aux_defined = self.training and self.aux_logits
#     168         if torch.jit.is_scripting():
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/inception.py in _forward(self, x)
#     138                 aux = self.AuxLogits(x)
#     139         # N x 768 x 17 x 17
# --> 140         x = self.Mixed_7a(x)
#     141         # N x 1280 x 8 x 8
#     142         x = self.Mixed_7b(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/inception.py in forward(self, x)
#     314
#     315     def forward(self, x: Tensor) -> Tensor:
# --> 316         outputs = self._forward(x)
#     317         return torch.cat(outputs, 1)
#     318
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/inception.py in _forward(self, x)
#     302     def _forward(self, x: Tensor) -> List[Tensor]:
#     303         branch3x3 = self.branch3x3_1(x)
# --> 304         branch3x3 = self.branch3x3_2(branch3x3)
#     305
#     306         branch7x7x3 = self.branch7x7x3_1(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torchvision/models/inception.py in forward(self, x)
#     403
#     404     def forward(self, x: Tensor) -> Tensor:
# --> 405         x = self.conv(x)
#     406         x = self.bn(x)
#     407         return F.relu(x, inplace=True)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# RuntimeError: Calculated padded input size per channel: (1 x 1). Kernel size: (3 x 3). Kernel size can't be greater than actual input size

# %%
def calculate_activations(
        data: torch.Tensor,
        batch_size: int = 32,
        verbose: bool = False
) -> torch.Tensor:
    # Calculate activations of Pool3 layer of InceptionV3
    if verbose:
        print("Calculating activations...")
    activations = predict(inception, data, batch_size=32)
    return activations

def calculate_activation_statistics(
        activations: torch.Tensor
) -> tp.Tuple[np.array, np.array]:
    activations = activations.numpy().reshape(len(activations), -1)
    # Calculate mean and covariance of activations. Mind the dimensions!
    mu = activations.mean(axis=0)
    t = activations - mu
    sigma = (t.T @ t) / t.shape[0]
    return mu, sigma

# %%
real_activations = calculate_activations(lr_data, verbose=True)
real_mu, real_sigma = calculate_activation_statistics(real_activations)

assert real_mu.shape == (2048,)
assert real_sigma.shape == (2048, 2048)
# Out:
# Calculating activations...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-f388f6f939bf> in <module>
# ----> 1 real_activations = calculate_activations(lr_data, verbose=True)
#       2 real_mu, real_sigma = calculate_activation_statistics(real_activations)
#       3
#       4 assert real_mu.shape == (2048,)
#       5 assert real_sigma.shape == (2048, 2048)
#
# <ipython-input-135-1ca04b80759a> in calculate_activations(data, batch_size, verbose)
#       7     if verbose:
#       8         print("Calculating activations...")
# ----> 9     activations = predict(inception, data, batch_size=32)
#      10     return activations
#      11
#
# NameError: name 'inception' is not defined

# %%
import scipy

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    assert mu1.shape == mu2.shape
    assert sigma1.shape == sigma2.shape

    sigma1_sigma2 = scipy.linalg.sqrtm(np.dot(sigma1, sigma2))

    # Numerical error might give slight imaginary component
    if np.iscomplexobj(sigma1_sigma2):
        sigma1_sigma2 = sigma1_sigma2.real

    # Product might be almost singular
    if not np.isfinite(sigma1_sigma2).all():
        offset = np.eye(sigma1.shape[0]) * eps
        sigma1_sigma2 = scipy.linalg.sqrtm(np.dot(sigma1 + offset, sigma2 + offset))

    diff = mu1 - mu2
    
    # use diff, sigma1, sigma2 to calculate FID according to the formula above
    return  # TODO: implement score from paper


def calculate_fid_score(real_data, fake_data, verbose=False):
    # Run inception on real and fake data to obtain activations
    real_activations = # TODO
    fake_activations = # TODO

    # Calculate mu and sigma for both real and fake activations
    real_mu, real_sigma = # TODO
    fake_mu, fake_sigma = # TODO

    return calculate_frechet_distance(real_mu, real_sigma, fake_mu, fake_sigma) # calculate Frechet distance

# %% [markdown]
# Calculate FID score between `hr_data` and `sr_fake_data_from_real_hr`:

# %%
score = calculate_fid_score(hr_data, sr_fake_data_from_real_lr)
print("Score:", score)

# %% [markdown]
# Putting it all together: calculate FID score between `hr_data` and `sr_fake_data_from_fake_hr`:

# %%
score = calculate_fid_score(hr_data, sr_fake_data_from_fake_lr)
print("Score:", score)
